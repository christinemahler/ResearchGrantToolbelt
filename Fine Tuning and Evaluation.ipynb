# %% [markdown]
# ### Check Python Version
# I encountered some issues with configuring the sentence transformers and initially tried changing the Python version. While this fixed the sentence transformers issues I was having, it broke the langchain modules as they don't appear to work with Python 3.13 just yet. I'm leaving this code in here though in case it comes in handy at a later time.

# %%
# !python --version
# Out:
# Python 3.11.11

# %% [markdown]
# ### Change Python Version
# Below is the code used to change the Python version used in this notebook and which was found in the following Stack Overflow thread: https://stackoverflow.com/questions/68657341/how-can-i-update-google-colabs-python-version

# %%
#install python 3.13
# !sudo apt-get update -y
# !sudo apt-get install python3.13

#change alternatives
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.11 1
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.13 2

#check python version
# !python --version
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,317 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,662 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,610 kB]
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,703 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,939 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,230 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,526 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Fetched 21.4 MB in 2s (9,173 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpython3.13-stdlib
# Suggested packages:
#   python3.13-venv
# The following NEW packages will be installed:
#   libpython3.13-stdlib python3.13
# 0 upgraded, 2 newly installed, 0 to remove and 32 not upgraded.
# Need to get 5,527 kB of archives.
# After this operation, 21.8 MB of additional disk space will be used.
# Get:1 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.13-stdlib amd64 3.13.2-1+jammy1 [3,004 kB]
# Get:2 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.13 amd64 3.13.2-1+jammy1 [2,522 kB]
# Fetched 5,527 kB in 11s (489 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libpython3.13-stdlib:amd64.
# (Reading database ... 124926 files and directories currently installed.)
# Preparing to unpack .../libpython3.13-stdlib_3.13.2-1+jammy1_amd64.deb ...
# Unpacking libpython3.13-stdlib:amd64 (3.13.2-1+jammy1) ...
# Selecting previously unselected package python3.13.
# Preparing to unpack .../python3.13_3.13.2-1+jammy1_amd64.deb ...
# Unpacking python3.13 (3.13.2-1+jammy1) ...
# Setting up libpython3.13-stdlib:amd64 (3.13.2-1+jammy1) ...
# Setting up python3.13 (3.13.2-1+jammy1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# update-alternatives: using /usr/bin/python3.13 to provide /usr/bin/python3 (python3) in auto mode
# Python 3.13.2

# %% [markdown]
# ### Install Pip
# You have to install pip again after changing the Python version. Below is the code to do so.

# %%
# install pip for new python
# !sudo apt-get install python3.13-distutils
# !wget https://bootstrap.pypa.io/get-pip.py
# !python get-pip.py

# credit of these last two commands blongs to @Erik
# install colab's dependencies
# !python -m pip install ipython ipython_genutils ipykernel jupyter_console prompt_toolkit httplib2 astor

# link to the old google package
# !ln -s /usr/local/lib/python3.11/dist-packages/google \
       /usr/local/lib/python3.13/dist-packages/google
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package python3.13-distutils
# E: Couldn't find any package by glob 'python3.13-distutils'
# E: Couldn't find any package by regex 'python3.13-distutils'
# --2025-02-23 04:23:20--  https://bootstrap.pypa.io/get-pip.py
# Resolving bootstrap.pypa.io (bootstrap.pypa.io)... 151.101.0.175, 151.101.64.175, 151.101.128.175, ...
# Connecting to bootstrap.pypa.io (bootstrap.pypa.io)|151.101.0.175|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2300175 (2.2M) [text/x-python]
# Saving to: ‘get-pip.py’
#
# get-pip.py          100%[===================>]   2.19M  --.-KB/s    in 0.04s
#
# 2025-02-23 04:23:20 (51.9 MB/s) - ‘get-pip.py’ saved [2300175/2300175]
#
# Collecting pip
#   Downloading pip-25.0.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-25.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 11.2 MB/s eta 0:00:00
# Installing collected packages: pip
# Successfully installed pip-25.0.1
# Collecting ipython
#   Downloading ipython-8.32.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting ipython_genutils
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Collecting ipykernel
#   Downloading ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jupyter_console
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting prompt_toolkit
#   Downloading prompt_toolkit-3.0.50-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: httplib2 in /usr/lib/python3/dist-packages (0.20.2)
# Collecting astor
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting decorator (from ipython)
#   Downloading decorator-5.2.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting jedi>=0.16 (from ipython)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting matplotlib-inline (from ipython)
#   Downloading matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting pexpect>4.3 (from ipython)
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pygments>=2.4.0 (from ipython)
#   Downloading pygments-2.19.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data (from ipython)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting traitlets>=5.13.0 (from ipython)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting comm>=0.1.1 (from ipykernel)
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting debugpy>=1.6.5 (from ipykernel)
#   Downloading debugpy-1.8.12-cp313-cp313-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting jupyter-client>=6.1.12 (from ipykernel)
#   Downloading jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter-core!=5.0.*,>=4.12 (from ipykernel)
#   Downloading jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting nest-asyncio (from ipykernel)
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting packaging (from ipykernel)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting psutil (from ipykernel)
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyzmq>=24 (from ipykernel)
#   Downloading pyzmq-26.2.1-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (6.2 kB)
# Collecting tornado>=6.1 (from ipykernel)
#   Downloading tornado-6.4.2-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting wcwidth (from prompt_toolkit)
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/lib/python3/dist-packages (from httplib2) (2.4.7)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython)
#   Downloading parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting python-dateutil>=2.8.2 (from jupyter-client>=6.1.12->ipykernel)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting platformdirs>=2.5 (from jupyter-core!=5.0.*,>=4.12->ipykernel)
#   Downloading platformdirs-4.3.6-py3-none-any.whl.metadata (11 kB)
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting executing>=1.2.0 (from stack_data->ipython)
#   Downloading executing-2.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython)
#   Downloading asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack_data->ipython)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Downloading ipython-8.32.0-py3-none-any.whl (825 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.5/825.5 kB 26.2 MB/s eta 0:00:00
# Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading prompt_toolkit-3.0.50-py3-none-any.whl (387 kB)
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading debugpy-1.8.12-cp313-cp313-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 79.0 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 76.3 MB/s eta 0:00:00
# Downloading jupyter_client-8.6.3-py3-none-any.whl (106 kB)
# Downloading jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Downloading matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Downloading pygments-2.19.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 62.0 MB/s eta 0:00:00
# Downloading pyzmq-26.2.1-cp313-cp313-manylinux_2_28_x86_64.whl (865 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.7/865.7 kB 47.0 MB/s eta 0:00:00
# Downloading tornado-6.4.2-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (437 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading decorator-5.2.0-py3-none-any.whl (9.1 kB)
# Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
# Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Downloading executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Downloading parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Downloading platformdirs-4.3.6-py3-none-any.whl (18 kB)
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Installing collected packages: wcwidth, pure-eval, ptyprocess, ipython_genutils, traitlets, tornado, pyzmq, python-dateutil, pygments, psutil, prompt_toolkit, platformdirs, pexpect, parso, packaging, nest-asyncio, executing, decorator, debugpy, asttokens, astor, stack_data, matplotlib-inline, jupyter-core, jedi, comm, jupyter-client, ipython, ipykernel, jupyter_console
# Successfully installed astor-0.8.1 asttokens-3.0.0 comm-0.2.2 debugpy-1.8.12 decorator-5.2.0 executing-2.2.0 ipykernel-6.29.5 ipython-8.32.0 ipython_genutils-0.2.0 jedi-0.19.2 jupyter-client-8.6.3 jupyter-core-5.7.2 jupyter_console-6.6.3 matplotlib-inline-0.1.7 nest-asyncio-1.6.0 packaging-24.2 parso-0.8.4 pexpect-4.9.0 platformdirs-4.3.6 prompt_toolkit-3.0.50 psutil-7.0.0 ptyprocess-0.7.0 pure-eval-0.2.3 pygments-2.19.1 python-dateutil-2.9.0.post0 pyzmq-26.2.1 stack_data-0.6.3 tornado-6.4.2 traitlets-5.14.3 wcwidth-0.2.13

# %% [markdown]
# ### Enable Async Features
# Async should speed up the test question creation process later.

# %%
import nest_asyncio

nest_asyncio.apply()

# %% [markdown]
# ### List Packages
# Could be useful later on when trying to reconcile package dependency issues.

# %%
# !pip list -v
# Out:
# Package                            Version             Location                                Installer
# ---------------------------------- ------------------- --------------------------------------- ---------
# absl-py                            1.4.0               /usr/local/lib/python3.11/dist-packages uv
# accelerate                         1.3.0               /usr/local/lib/python3.11/dist-packages uv
# aiohappyeyeballs                   2.4.6               /usr/local/lib/python3.11/dist-packages uv
# aiohttp                            3.11.12             /usr/local/lib/python3.11/dist-packages uv
# aiosignal                          1.3.2               /usr/local/lib/python3.11/dist-packages uv
# alabaster                          1.0.0               /usr/local/lib/python3.11/dist-packages uv
# albucore                           0.0.23              /usr/local/lib/python3.11/dist-packages uv
# albumentations                     2.0.4               /usr/local/lib/python3.11/dist-packages uv
# ale-py                             0.10.2              /usr/local/lib/python3.11/dist-packages uv
# altair                             5.5.0               /usr/local/lib/python3.11/dist-packages uv
# annotated-types                    0.7.0               /usr/local/lib/python3.11/dist-packages uv
# anyio                              3.7.1               /usr/local/lib/python3.11/dist-packages uv
# argon2-cffi                        23.1.0              /usr/local/lib/python3.11/dist-packages uv
# argon2-cffi-bindings               21.2.0              /usr/local/lib/python3.11/dist-packages uv
# array_record                       0.6.0               /usr/local/lib/python3.11/dist-packages uv
# arviz                              0.20.0              /usr/local/lib/python3.11/dist-packages uv
# astropy                            7.0.1               /usr/local/lib/python3.11/dist-packages uv
# astropy-iers-data                  0.2025.2.17.0.34.13 /usr/local/lib/python3.11/dist-packages uv
# astunparse                         1.6.3               /usr/local/lib/python3.11/dist-packages uv
# atpublic                           4.1.0               /usr/local/lib/python3.11/dist-packages uv
# attrs                              25.1.0              /usr/local/lib/python3.11/dist-packages uv
# audioread                          3.0.1               /usr/local/lib/python3.11/dist-packages uv
# autograd                           1.7.0               /usr/local/lib/python3.11/dist-packages uv
# babel                              2.17.0              /usr/local/lib/python3.11/dist-packages uv
# backcall                           0.2.0               /usr/local/lib/python3.11/dist-packages uv
# beautifulsoup4                     4.13.3              /usr/local/lib/python3.11/dist-packages uv
# betterproto                        2.0.0b6             /usr/local/lib/python3.11/dist-packages uv
# bigframes                          1.37.0              /usr/local/lib/python3.11/dist-packages uv
# bigquery-magics                    0.6.0               /usr/local/lib/python3.11/dist-packages uv
# bleach                             6.2.0               /usr/local/lib/python3.11/dist-packages uv
# blinker                            1.9.0               /usr/local/lib/python3.11/dist-packages uv
# blis                               0.7.11              /usr/local/lib/python3.11/dist-packages uv
# blosc2                             3.1.1               /usr/local/lib/python3.11/dist-packages uv
# bokeh                              3.6.3               /usr/local/lib/python3.11/dist-packages uv
# Bottleneck                         1.4.2               /usr/local/lib/python3.11/dist-packages uv
# bqplot                             0.12.44             /usr/local/lib/python3.11/dist-packages uv
# branca                             0.8.1               /usr/local/lib/python3.11/dist-packages uv
# CacheControl                       0.14.2              /usr/local/lib/python3.11/dist-packages uv
# cachetools                         5.5.1               /usr/local/lib/python3.11/dist-packages uv
# catalogue                          2.0.10              /usr/local/lib/python3.11/dist-packages uv
# certifi                            2025.1.31           /usr/local/lib/python3.11/dist-packages uv
# cffi                               1.17.1              /usr/local/lib/python3.11/dist-packages uv
# chardet                            5.2.0               /usr/local/lib/python3.11/dist-packages uv
# charset-normalizer                 3.4.1               /usr/local/lib/python3.11/dist-packages uv
# chex                               0.1.88              /usr/local/lib/python3.11/dist-packages uv
# clarabel                           0.10.0              /usr/local/lib/python3.11/dist-packages uv
# click                              8.1.8               /usr/local/lib/python3.11/dist-packages uv
# cloudpathlib                       0.20.0              /usr/local/lib/python3.11/dist-packages uv
# cloudpickle                        3.1.1               /usr/local/lib/python3.11/dist-packages uv
# cmake                              3.31.4              /usr/local/lib/python3.11/dist-packages uv
# cmdstanpy                          1.2.5               /usr/local/lib/python3.11/dist-packages uv
# colorcet                           3.1.0               /usr/local/lib/python3.11/dist-packages uv
# colorlover                         0.3.0               /usr/local/lib/python3.11/dist-packages uv
# colour                             0.1.5               /usr/local/lib/python3.11/dist-packages uv
# community                          1.0.0b1             /usr/local/lib/python3.11/dist-packages uv
# confection                         0.1.5               /usr/local/lib/python3.11/dist-packages uv
# cons                               0.4.6               /usr/local/lib/python3.11/dist-packages uv
# contourpy                          1.3.1               /usr/local/lib/python3.11/dist-packages uv
# cramjam                            2.9.1               /usr/local/lib/python3.11/dist-packages uv
# cryptography                       43.0.3              /usr/local/lib/python3.11/dist-packages uv
# cuda-python                        12.6.0              /usr/local/lib/python3.11/dist-packages uv
# cudf-cu12                          24.12.0             /usr/local/lib/python3.11/dist-packages uv
# cufflinks                          0.17.3              /usr/local/lib/python3.11/dist-packages uv
# cupy-cuda12x                       13.3.0              /usr/local/lib/python3.11/dist-packages uv
# cvxopt                             1.3.2               /usr/local/lib/python3.11/dist-packages uv
# cvxpy                              1.6.0               /usr/local/lib/python3.11/dist-packages uv
# cycler                             0.12.1              /usr/local/lib/python3.11/dist-packages uv
# cyipopt                            1.5.0               /usr/local/lib/python3.11/dist-packages uv
# cymem                              2.0.11              /usr/local/lib/python3.11/dist-packages uv
# Cython                             3.0.12              /usr/local/lib/python3.11/dist-packages uv
# dask                               2024.10.0           /usr/local/lib/python3.11/dist-packages uv
# dataclasses-json                   0.6.7               /usr/local/lib/python3.11/dist-packages pip
# datascience                        0.17.6              /usr/local/lib/python3.11/dist-packages uv
# db-dtypes                          1.4.1               /usr/local/lib/python3.11/dist-packages uv
# dbus-python                        1.2.18              /usr/lib/python3/dist-packages
# debugpy                            1.8.0               /usr/local/lib/python3.11/dist-packages uv
# decorator                          4.4.2               /usr/local/lib/python3.11/dist-packages uv
# defusedxml                         0.7.1               /usr/local/lib/python3.11/dist-packages uv
# Deprecated                         1.2.18              /usr/local/lib/python3.11/dist-packages uv
# diffusers                          0.32.2              /usr/local/lib/python3.11/dist-packages uv
# distro                             1.9.0               /usr/local/lib/python3.11/dist-packages uv
# dlib                               19.24.2             /usr/local/lib/python3.11/dist-packages uv
# dm-tree                            0.1.9               /usr/local/lib/python3.11/dist-packages uv
# docker-pycreds                     0.4.0               /usr/local/lib/python3.11/dist-packages uv
# docstring_parser                   0.16                /usr/local/lib/python3.11/dist-packages uv
# docutils                           0.21.2              /usr/local/lib/python3.11/dist-packages uv
# dopamine_rl                        4.1.2               /usr/local/lib/python3.11/dist-packages uv
# duckdb                             1.1.3               /usr/local/lib/python3.11/dist-packages uv
# earthengine-api                    1.5.3               /usr/local/lib/python3.11/dist-packages uv
# easydict                           1.13                /usr/local/lib/python3.11/dist-packages uv
# editdistance                       0.8.1               /usr/local/lib/python3.11/dist-packages uv
# eerepr                             0.1.1               /usr/local/lib/python3.11/dist-packages uv
# einops                             0.8.1               /usr/local/lib/python3.11/dist-packages uv
# en-core-web-sm                     3.7.1               /usr/local/lib/python3.11/dist-packages pip
# entrypoints                        0.4                 /usr/local/lib/python3.11/dist-packages uv
# et_xmlfile                         2.0.0               /usr/local/lib/python3.11/dist-packages uv
# etils                              1.12.0              /usr/local/lib/python3.11/dist-packages uv
# etuples                            0.3.9               /usr/local/lib/python3.11/dist-packages uv
# Farama-Notifications               0.0.4               /usr/local/lib/python3.11/dist-packages uv
# fastai                             2.7.18              /usr/local/lib/python3.11/dist-packages uv
# fastcore                           1.7.29              /usr/local/lib/python3.11/dist-packages uv
# fastdownload                       0.0.7               /usr/local/lib/python3.11/dist-packages uv
# fastjsonschema                     2.21.1              /usr/local/lib/python3.11/dist-packages uv
# fastprogress                       1.0.3               /usr/local/lib/python3.11/dist-packages uv
# fastrlock                          0.8.3               /usr/local/lib/python3.11/dist-packages uv
# filelock                           3.17.0              /usr/local/lib/python3.11/dist-packages uv
# firebase-admin                     6.6.0               /usr/local/lib/python3.11/dist-packages uv
# Flask                              3.1.0               /usr/local/lib/python3.11/dist-packages uv
# flatbuffers                        25.2.10             /usr/local/lib/python3.11/dist-packages uv
# flax                               0.10.3              /usr/local/lib/python3.11/dist-packages uv
# folium                             0.19.4              /usr/local/lib/python3.11/dist-packages uv
# fonttools                          4.56.0              /usr/local/lib/python3.11/dist-packages uv
# frozendict                         2.4.6               /usr/local/lib/python3.11/dist-packages uv
# frozenlist                         1.5.0               /usr/local/lib/python3.11/dist-packages uv
# fsspec                             2024.10.0           /usr/local/lib/python3.11/dist-packages uv
# future                             1.0.0               /usr/local/lib/python3.11/dist-packages uv
# gast                               0.6.0               /usr/local/lib/python3.11/dist-packages uv
# gcsfs                              2024.10.0           /usr/local/lib/python3.11/dist-packages uv
# GDAL                               3.6.4               /usr/local/lib/python3.11/dist-packages uv
# gdown                              5.2.0               /usr/local/lib/python3.11/dist-packages uv
# geemap                             0.35.1              /usr/local/lib/python3.11/dist-packages uv
# gensim                             4.3.3               /usr/local/lib/python3.11/dist-packages uv
# geocoder                           1.38.1              /usr/local/lib/python3.11/dist-packages uv
# geographiclib                      2.0                 /usr/local/lib/python3.11/dist-packages uv
# geopandas                          1.0.1               /usr/local/lib/python3.11/dist-packages uv
# geopy                              2.4.1               /usr/local/lib/python3.11/dist-packages uv
# gin-config                         0.5.0               /usr/local/lib/python3.11/dist-packages uv
# gitdb                              4.0.12              /usr/local/lib/python3.11/dist-packages uv
# GitPython                          3.1.44              /usr/local/lib/python3.11/dist-packages uv
# glob2                              0.7                 /usr/local/lib/python3.11/dist-packages uv
# google                             2.0.3               /usr/local/lib/python3.11/dist-packages uv
# google-ai-generativelanguage       0.6.15              /usr/local/lib/python3.11/dist-packages uv
# google-api-core                    2.24.1              /usr/local/lib/python3.11/dist-packages uv
# google-api-python-client           2.160.0             /usr/local/lib/python3.11/dist-packages uv
# google-auth                        2.27.0              /usr/local/lib/python3.11/dist-packages uv
# google-auth-httplib2               0.2.0               /usr/local/lib/python3.11/dist-packages uv
# google-auth-oauthlib               1.2.1               /usr/local/lib/python3.11/dist-packages uv
# google-cloud-aiplatform            1.79.0              /usr/local/lib/python3.11/dist-packages uv
# google-cloud-bigquery              3.29.0              /usr/local/lib/python3.11/dist-packages uv
# google-cloud-bigquery-connection   1.18.0              /usr/local/lib/python3.11/dist-packages uv
# google-cloud-bigquery-storage      2.28.0              /usr/local/lib/python3.11/dist-packages uv
# google-cloud-bigtable              2.28.1              /usr/local/lib/python3.11/dist-packages uv
# google-cloud-core                  2.4.1               /usr/local/lib/python3.11/dist-packages uv
# google-cloud-dataproc              5.17.0              /usr/local/lib/python3.11/dist-packages uv
# google-cloud-datastore             2.20.2              /usr/local/lib/python3.11/dist-packages uv
# google-cloud-firestore             2.20.0              /usr/local/lib/python3.11/dist-packages uv
# google-cloud-functions             1.19.0              /usr/local/lib/python3.11/dist-packages uv
# google-cloud-iam                   2.18.0              /usr/local/lib/python3.11/dist-packages uv
# google-cloud-language              2.16.0              /usr/local/lib/python3.11/dist-packages uv
# google-cloud-pubsub                2.25.0              /usr/local/lib/python3.11/dist-packages uv
# google-cloud-resource-manager      1.14.0              /usr/local/lib/python3.11/dist-packages uv
# google-cloud-spanner               3.51.0              /usr/local/lib/python3.11/dist-packages uv
# google-cloud-storage               2.19.0              /usr/local/lib/python3.11/dist-packages uv
# google-cloud-translate             3.19.0              /usr/local/lib/python3.11/dist-packages uv
# google-colab                       1.0.0               /usr/local/lib/python3.11/dist-packages uv
# google-crc32c                      1.6.0               /usr/local/lib/python3.11/dist-packages uv
# google-genai                       0.8.0               /usr/local/lib/python3.11/dist-packages uv
# google-generativeai                0.8.4               /usr/local/lib/python3.11/dist-packages uv
# google-pasta                       0.2.0               /usr/local/lib/python3.11/dist-packages uv
# google-resumable-media             2.7.2               /usr/local/lib/python3.11/dist-packages uv
# google-spark-connect               0.5.2               /usr/local/lib/python3.11/dist-packages uv
# googleapis-common-protos           1.67.0              /usr/local/lib/python3.11/dist-packages uv
# googledrivedownloader              1.1.0               /usr/local/lib/python3.11/dist-packages uv
# graphviz                           0.20.3              /usr/local/lib/python3.11/dist-packages uv
# greenlet                           3.1.1               /usr/local/lib/python3.11/dist-packages uv
# grpc-google-iam-v1                 0.14.0              /usr/local/lib/python3.11/dist-packages uv
# grpc-interceptor                   0.15.4              /usr/local/lib/python3.11/dist-packages uv
# grpcio                             1.70.0              /usr/local/lib/python3.11/dist-packages uv
# grpcio-status                      1.62.3              /usr/local/lib/python3.11/dist-packages uv
# grpclib                            0.4.7               /usr/local/lib/python3.11/dist-packages uv
# gspread                            6.1.4               /usr/local/lib/python3.11/dist-packages uv
# gspread-dataframe                  4.0.0               /usr/local/lib/python3.11/dist-packages uv
# gym                                0.25.2              /usr/local/lib/python3.11/dist-packages uv
# gym-notices                        0.0.8               /usr/local/lib/python3.11/dist-packages uv
# gymnasium                          1.0.0               /usr/local/lib/python3.11/dist-packages uv
# h11                                0.14.0              /usr/local/lib/python3.11/dist-packages uv
# h2                                 4.2.0               /usr/local/lib/python3.11/dist-packages uv
# h5netcdf                           1.5.0               /usr/local/lib/python3.11/dist-packages uv
# h5py                               3.12.1              /usr/local/lib/python3.11/dist-packages uv
# highspy                            1.9.0               /usr/local/lib/python3.11/dist-packages uv
# holidays                           0.67                /usr/local/lib/python3.11/dist-packages uv
# holoviews                          1.20.1              /usr/local/lib/python3.11/dist-packages uv
# hpack                              4.1.0               /usr/local/lib/python3.11/dist-packages uv
# html5lib                           1.1                 /usr/local/lib/python3.11/dist-packages uv
# httpcore                           1.0.7               /usr/local/lib/python3.11/dist-packages uv
# httpimport                         1.4.0               /usr/local/lib/python3.11/dist-packages uv
# httplib2                           0.22.0              /usr/local/lib/python3.11/dist-packages uv
# httpx                              0.28.1              /usr/local/lib/python3.11/dist-packages uv
# httpx-sse                          0.4.0               /usr/local/lib/python3.11/dist-packages pip
# huggingface-hub                    0.28.1              /usr/local/lib/python3.11/dist-packages uv
# humanize                           4.11.0              /usr/local/lib/python3.11/dist-packages uv
# hyperframe                         6.1.0               /usr/local/lib/python3.11/dist-packages uv
# hyperopt                           0.2.7               /usr/local/lib/python3.11/dist-packages uv
# ibis-framework                     9.2.0               /usr/local/lib/python3.11/dist-packages uv
# idna                               3.10                /usr/local/lib/python3.11/dist-packages uv
# imageio                            2.37.0              /usr/local/lib/python3.11/dist-packages uv
# imageio-ffmpeg                     0.6.0               /usr/local/lib/python3.11/dist-packages uv
# imagesize                          1.4.1               /usr/local/lib/python3.11/dist-packages uv
# imbalanced-learn                   0.13.0              /usr/local/lib/python3.11/dist-packages uv
# imgaug                             0.4.0               /usr/local/lib/python3.11/dist-packages uv
# immutabledict                      4.2.1               /usr/local/lib/python3.11/dist-packages uv
# importlib_metadata                 8.6.1               /usr/local/lib/python3.11/dist-packages uv
# importlib_resources                6.5.2               /usr/local/lib/python3.11/dist-packages uv
# imutils                            0.5.4               /usr/local/lib/python3.11/dist-packages uv
# inflect                            7.5.0               /usr/local/lib/python3.11/dist-packages uv
# iniconfig                          2.0.0               /usr/local/lib/python3.11/dist-packages uv
# intel-cmplr-lib-ur                 2025.0.4            /usr/local/lib/python3.11/dist-packages uv
# intel-openmp                       2025.0.4            /usr/local/lib/python3.11/dist-packages uv
# ipyevents                          2.0.2               /usr/local/lib/python3.11/dist-packages uv
# ipyfilechooser                     0.6.0               /usr/local/lib/python3.11/dist-packages uv
# ipykernel                          6.17.1              /usr/local/lib/python3.11/dist-packages uv
# ipyleaflet                         0.19.2              /usr/local/lib/python3.11/dist-packages uv
# ipyparallel                        8.8.0               /usr/local/lib/python3.11/dist-packages uv
# ipython                            7.34.0              /usr/local/lib/python3.11/dist-packages uv
# ipython-genutils                   0.2.0               /usr/local/lib/python3.11/dist-packages uv
# ipython-sql                        0.5.0               /usr/local/lib/python3.11/dist-packages uv
# ipytree                            0.2.2               /usr/local/lib/python3.11/dist-packages uv
# ipywidgets                         7.7.1               /usr/local/lib/python3.11/dist-packages uv
# itsdangerous                       2.2.0               /usr/local/lib/python3.11/dist-packages uv
# jax                                0.4.33              /usr/local/lib/python3.11/dist-packages uv
# jax-cuda12-pjrt                    0.4.33              /usr/local/lib/python3.11/dist-packages uv
# jax-cuda12-plugin                  0.4.33              /usr/local/lib/python3.11/dist-packages uv
# jaxlib                             0.4.33              /usr/local/lib/python3.11/dist-packages uv
# jeepney                            0.7.1               /usr/lib/python3/dist-packages          flit
# jellyfish                          1.1.0               /usr/local/lib/python3.11/dist-packages uv
# jieba                              0.42.1              /usr/local/lib/python3.11/dist-packages uv
# Jinja2                             3.1.5               /usr/local/lib/python3.11/dist-packages uv
# jiter                              0.8.2               /usr/local/lib/python3.11/dist-packages uv
# joblib                             1.4.2               /usr/local/lib/python3.11/dist-packages uv
# jsonpatch                          1.33                /usr/local/lib/python3.11/dist-packages uv
# jsonpickle                         4.0.2               /usr/local/lib/python3.11/dist-packages uv
# jsonpointer                        3.0.0               /usr/local/lib/python3.11/dist-packages uv
# jsonschema                         4.23.0              /usr/local/lib/python3.11/dist-packages uv
# jsonschema-specifications          2024.10.1           /usr/local/lib/python3.11/dist-packages uv
# jupyter-client                     6.1.12              /usr/local/lib/python3.11/dist-packages uv
# jupyter-console                    6.1.0               /usr/local/lib/python3.11/dist-packages uv
# jupyter_core                       5.7.2               /usr/local/lib/python3.11/dist-packages uv
# jupyter-leaflet                    0.19.2              /usr/local/lib/python3.11/dist-packages uv
# jupyter-server                     1.24.0              /usr/local/lib/python3.11/dist-packages uv
# jupyterlab_pygments                0.3.0               /usr/local/lib/python3.11/dist-packages uv
# jupyterlab_widgets                 3.0.13              /usr/local/lib/python3.11/dist-packages uv
# kaggle                             1.6.17              /usr/local/lib/python3.11/dist-packages uv
# kagglehub                          0.3.9               /usr/local/lib/python3.11/dist-packages uv
# keras                              3.8.0               /usr/local/lib/python3.11/dist-packages uv
# keras-hub                          0.18.1              /usr/local/lib/python3.11/dist-packages uv
# keras-nlp                          0.18.1              /usr/local/lib/python3.11/dist-packages uv
# keyring                            23.5.0              /usr/lib/python3/dist-packages
# kiwisolver                         1.4.8               /usr/local/lib/python3.11/dist-packages uv
# langchain                          0.3.13              /usr/local/lib/python3.11/dist-packages pip
# langchain-community                0.3.13              /usr/local/lib/python3.11/dist-packages pip
# langchain-core                     0.3.28              /usr/local/lib/python3.11/dist-packages pip
# langchain-huggingface              0.1.2               /usr/local/lib/python3.11/dist-packages pip
# langchain-openai                   0.2.14              /usr/local/lib/python3.11/dist-packages pip
# langchain-text-splitters           0.3.4               /usr/local/lib/python3.11/dist-packages pip
# langcodes                          3.5.0               /usr/local/lib/python3.11/dist-packages uv
# langsmith                          0.2.11              /usr/local/lib/python3.11/dist-packages pip
# language_data                      1.3.0               /usr/local/lib/python3.11/dist-packages uv
# launchpadlib                       1.10.16             /usr/lib/python3/dist-packages
# lazr.restfulclient                 0.14.4              /usr/lib/python3/dist-packages
# lazr.uri                           1.0.6               /usr/lib/python3/dist-packages
# lazy_loader                        0.4                 /usr/local/lib/python3.11/dist-packages uv
# libclang                           18.1.1              /usr/local/lib/python3.11/dist-packages uv
# libcudf-cu12                       24.12.0             /usr/local/lib/python3.11/dist-packages uv
# libkvikio-cu12                     24.12.1             /usr/local/lib/python3.11/dist-packages uv
# librosa                            0.10.2.post1        /usr/local/lib/python3.11/dist-packages uv
# lightgbm                           4.5.0               /usr/local/lib/python3.11/dist-packages uv
# linkify-it-py                      2.0.3               /usr/local/lib/python3.11/dist-packages uv
# llvmlite                           0.44.0              /usr/local/lib/python3.11/dist-packages uv
# locket                             1.0.0               /usr/local/lib/python3.11/dist-packages uv
# logical-unification                0.4.6               /usr/local/lib/python3.11/dist-packages uv
# lxml                               5.3.1               /usr/local/lib/python3.11/dist-packages uv
# marisa-trie                        1.2.1               /usr/local/lib/python3.11/dist-packages uv
# Markdown                           3.7                 /usr/local/lib/python3.11/dist-packages uv
# markdown-it-py                     3.0.0               /usr/local/lib/python3.11/dist-packages uv
# MarkupSafe                         3.0.2               /usr/local/lib/python3.11/dist-packages uv
# marshmallow                        3.26.1              /usr/local/lib/python3.11/dist-packages pip
# matplotlib                         3.10.0              /usr/local/lib/python3.11/dist-packages uv
# matplotlib-inline                  0.1.7               /usr/local/lib/python3.11/dist-packages uv
# matplotlib-venn                    1.1.1               /usr/local/lib/python3.11/dist-packages uv
# mdit-py-plugins                    0.4.2               /usr/local/lib/python3.11/dist-packages uv
# mdurl                              0.1.2               /usr/local/lib/python3.11/dist-packages uv
# miniKanren                         1.0.3               /usr/local/lib/python3.11/dist-packages uv
# missingno                          0.5.2               /usr/local/lib/python3.11/dist-packages uv
# mistune                            3.1.2               /usr/local/lib/python3.11/dist-packages uv
# mizani                             0.13.1              /usr/local/lib/python3.11/dist-packages uv
# mkl                                2025.0.1            /usr/local/lib/python3.11/dist-packages uv
# ml-dtypes                          0.4.1               /usr/local/lib/python3.11/dist-packages uv
# mlxtend                            0.23.4              /usr/local/lib/python3.11/dist-packages uv
# more-itertools                     10.6.0              /usr/local/lib/python3.11/dist-packages uv
# moviepy                            1.0.3               /usr/local/lib/python3.11/dist-packages uv
# mpmath                             1.3.0               /usr/local/lib/python3.11/dist-packages uv
# msgpack                            1.1.0               /usr/local/lib/python3.11/dist-packages uv
# multidict                          6.1.0               /usr/local/lib/python3.11/dist-packages uv
# multipledispatch                   1.0.0               /usr/local/lib/python3.11/dist-packages uv
# multitasking                       0.0.11              /usr/local/lib/python3.11/dist-packages uv
# murmurhash                         1.0.12              /usr/local/lib/python3.11/dist-packages uv
# music21                            9.3.0               /usr/local/lib/python3.11/dist-packages uv
# mypy-extensions                    1.0.0               /usr/local/lib/python3.11/dist-packages pip
# namex                              0.0.8               /usr/local/lib/python3.11/dist-packages uv
# narwhals                           1.27.1              /usr/local/lib/python3.11/dist-packages uv
# natsort                            8.4.0               /usr/local/lib/python3.11/dist-packages uv
# nbclassic                          1.2.0               /usr/local/lib/python3.11/dist-packages uv
# nbclient                           0.10.2              /usr/local/lib/python3.11/dist-packages uv
# nbconvert                          7.16.6              /usr/local/lib/python3.11/dist-packages uv
# nbformat                           5.10.4              /usr/local/lib/python3.11/dist-packages uv
# ndindex                            1.9.2               /usr/local/lib/python3.11/dist-packages uv
# nest-asyncio                       1.6.0               /usr/local/lib/python3.11/dist-packages uv
# networkx                           3.4.2               /usr/local/lib/python3.11/dist-packages uv
# nibabel                            5.3.2               /usr/local/lib/python3.11/dist-packages uv
# nltk                               3.9.1               /usr/local/lib/python3.11/dist-packages uv
# notebook                           6.5.5               /usr/local/lib/python3.11/dist-packages uv
# notebook_shim                      0.2.4               /usr/local/lib/python3.11/dist-packages uv
# numba                              0.61.0              /usr/local/lib/python3.11/dist-packages uv
# numba-cuda                         0.0.17.1            /usr/local/lib/python3.11/dist-packages uv
# numexpr                            2.10.2              /usr/local/lib/python3.11/dist-packages uv
# numpy                              1.26.4              /usr/local/lib/python3.11/dist-packages uv
# nvidia-cublas-cu12                 12.4.5.8            /usr/local/lib/python3.11/dist-packages pip
# nvidia-cuda-cupti-cu12             12.4.127            /usr/local/lib/python3.11/dist-packages pip
# nvidia-cuda-nvcc-cu12              12.5.82             /usr/local/lib/python3.11/dist-packages uv
# nvidia-cuda-nvrtc-cu12             12.4.127            /usr/local/lib/python3.11/dist-packages pip
# nvidia-cuda-runtime-cu12           12.4.127            /usr/local/lib/python3.11/dist-packages pip
# nvidia-cudnn-cu12                  9.1.0.70            /usr/local/lib/python3.11/dist-packages pip
# nvidia-cufft-cu12                  11.2.1.3            /usr/local/lib/python3.11/dist-packages pip
# nvidia-curand-cu12                 10.3.5.147          /usr/local/lib/python3.11/dist-packages pip
# nvidia-cusolver-cu12               11.6.1.9            /usr/local/lib/python3.11/dist-packages pip
# nvidia-cusparse-cu12               12.3.1.170          /usr/local/lib/python3.11/dist-packages pip
# nvidia-nccl-cu12                   2.21.5              /usr/local/lib/python3.11/dist-packages uv
# nvidia-nvcomp-cu12                 4.1.0.6             /usr/local/lib/python3.11/dist-packages uv
# nvidia-nvjitlink-cu12              12.4.127            /usr/local/lib/python3.11/dist-packages pip
# nvidia-nvtx-cu12                   12.4.127            /usr/local/lib/python3.11/dist-packages uv
# nvtx                               0.2.10              /usr/local/lib/python3.11/dist-packages uv
# nx-cugraph-cu12                    24.12.0             /usr/local/lib/python3.11/dist-packages uv
# oauth2client                       4.1.3               /usr/local/lib/python3.11/dist-packages uv
# oauthlib                           3.2.2               /usr/local/lib/python3.11/dist-packages uv
# openai                             1.61.1              /usr/local/lib/python3.11/dist-packages uv
# opencv-contrib-python              4.11.0.86           /usr/local/lib/python3.11/dist-packages uv
# opencv-python                      4.11.0.86           /usr/local/lib/python3.11/dist-packages uv
# opencv-python-headless             4.11.0.86           /usr/local/lib/python3.11/dist-packages uv
# openpyxl                           3.1.5               /usr/local/lib/python3.11/dist-packages uv
# opentelemetry-api                  1.16.0              /usr/local/lib/python3.11/dist-packages uv
# opentelemetry-sdk                  1.16.0              /usr/local/lib/python3.11/dist-packages uv
# opentelemetry-semantic-conventions 0.37b0              /usr/local/lib/python3.11/dist-packages uv
# opt_einsum                         3.4.0               /usr/local/lib/python3.11/dist-packages uv
# optax                              0.2.4               /usr/local/lib/python3.11/dist-packages uv
# optree                             0.14.0              /usr/local/lib/python3.11/dist-packages uv
# orbax-checkpoint                   0.6.4               /usr/local/lib/python3.11/dist-packages uv
# orjson                             3.10.15             /usr/local/lib/python3.11/dist-packages uv
# osqp                               0.6.7.post3         /usr/local/lib/python3.11/dist-packages uv
# packaging                          24.2                /usr/local/lib/python3.11/dist-packages uv
# pandas                             2.2.2               /usr/local/lib/python3.11/dist-packages uv
# pandas-datareader                  0.10.0              /usr/local/lib/python3.11/dist-packages uv
# pandas-gbq                         0.27.0              /usr/local/lib/python3.11/dist-packages uv
# pandas-stubs                       2.2.2.240909        /usr/local/lib/python3.11/dist-packages uv
# pandocfilters                      1.5.1               /usr/local/lib/python3.11/dist-packages uv
# panel                              1.6.1               /usr/local/lib/python3.11/dist-packages uv
# param                              2.2.0               /usr/local/lib/python3.11/dist-packages uv
# parso                              0.8.4               /usr/local/lib/python3.11/dist-packages uv
# parsy                              2.1                 /usr/local/lib/python3.11/dist-packages uv
# partd                              1.4.2               /usr/local/lib/python3.11/dist-packages uv
# pathlib                            1.0.1               /usr/local/lib/python3.11/dist-packages uv
# patsy                              1.0.1               /usr/local/lib/python3.11/dist-packages uv
# peewee                             3.17.9              /usr/local/lib/python3.11/dist-packages uv
# peft                               0.14.0              /usr/local/lib/python3.11/dist-packages uv
# pexpect                            4.9.0               /usr/local/lib/python3.11/dist-packages uv
# pickleshare                        0.7.5               /usr/local/lib/python3.11/dist-packages uv
# pillow                             11.1.0              /usr/local/lib/python3.11/dist-packages uv
# pip                                24.1.2              /usr/local/lib/python3.11/dist-packages uv
# platformdirs                       4.3.6               /usr/local/lib/python3.11/dist-packages uv
# plotly                             5.24.1              /usr/local/lib/python3.11/dist-packages uv
# plotnine                           0.14.5              /usr/local/lib/python3.11/dist-packages uv
# pluggy                             1.5.0               /usr/local/lib/python3.11/dist-packages uv
# ply                                3.11                /usr/local/lib/python3.11/dist-packages uv
# polars                             1.9.0               /usr/local/lib/python3.11/dist-packages uv
# pooch                              1.8.2               /usr/local/lib/python3.11/dist-packages uv
# portpicker                         1.5.2               /usr/local/lib/python3.11/dist-packages uv
# preshed                            3.0.9               /usr/local/lib/python3.11/dist-packages uv
# prettytable                        3.14.0              /usr/local/lib/python3.11/dist-packages uv
# proglog                            0.1.10              /usr/local/lib/python3.11/dist-packages uv
# progressbar2                       4.5.0               /usr/local/lib/python3.11/dist-packages uv
# prometheus_client                  0.21.1              /usr/local/lib/python3.11/dist-packages uv
# promise                            2.3                 /usr/local/lib/python3.11/dist-packages uv
# prompt_toolkit                     3.0.50              /usr/local/lib/python3.11/dist-packages uv
# propcache                          0.2.1               /usr/local/lib/python3.11/dist-packages uv
# prophet                            1.1.6               /usr/local/lib/python3.11/dist-packages uv
# proto-plus                         1.26.0              /usr/local/lib/python3.11/dist-packages uv
# protobuf                           4.25.6              /usr/local/lib/python3.11/dist-packages uv
# psutil                             5.9.5               /usr/local/lib/python3.11/dist-packages uv
# psycopg2                           2.9.10              /usr/local/lib/python3.11/dist-packages uv
# ptyprocess                         0.7.0               /usr/local/lib/python3.11/dist-packages uv
# py-cpuinfo                         9.0.0               /usr/local/lib/python3.11/dist-packages uv
# py4j                               0.10.9.7            /usr/local/lib/python3.11/dist-packages uv
# pyarrow                            17.0.0              /usr/local/lib/python3.11/dist-packages uv
# pyasn1                             0.6.1               /usr/local/lib/python3.11/dist-packages uv
# pyasn1_modules                     0.4.1               /usr/local/lib/python3.11/dist-packages uv
# pycocotools                        2.0.8               /usr/local/lib/python3.11/dist-packages uv
# pycparser                          2.22                /usr/local/lib/python3.11/dist-packages uv
# pydantic                           2.10.6              /usr/local/lib/python3.11/dist-packages uv
# pydantic_core                      2.27.2              /usr/local/lib/python3.11/dist-packages uv
# pydantic-settings                  2.8.0               /usr/local/lib/python3.11/dist-packages pip
# pydata-google-auth                 1.9.1               /usr/local/lib/python3.11/dist-packages uv
# pydot                              3.0.4               /usr/local/lib/python3.11/dist-packages uv
# pydotplus                          2.0.2               /usr/local/lib/python3.11/dist-packages uv
# PyDrive                            1.3.1               /usr/local/lib/python3.11/dist-packages uv
# PyDrive2                           1.21.3              /usr/local/lib/python3.11/dist-packages uv
# pyerfa                             2.0.1.5             /usr/local/lib/python3.11/dist-packages uv
# pygame                             2.6.1               /usr/local/lib/python3.11/dist-packages uv
# pygit2                             1.17.0              /usr/local/lib/python3.11/dist-packages uv
# Pygments                           2.18.0              /usr/local/lib/python3.11/dist-packages uv
# PyGObject                          3.42.1              /usr/lib/python3/dist-packages
# PyJWT                              2.10.1              /usr/local/lib/python3.11/dist-packages uv
# pylibcudf-cu12                     24.12.0             /usr/local/lib/python3.11/dist-packages uv
# pylibcugraph-cu12                  24.12.0             /usr/local/lib/python3.11/dist-packages uv
# pylibraft-cu12                     24.12.0             /usr/local/lib/python3.11/dist-packages uv
# pymc                               5.20.1              /usr/local/lib/python3.11/dist-packages uv
# pymystem3                          0.2.0               /usr/local/lib/python3.11/dist-packages uv
# pynvjitlink-cu12                   0.5.0               /usr/local/lib/python3.11/dist-packages uv
# pyogrio                            0.10.0              /usr/local/lib/python3.11/dist-packages uv
# Pyomo                              6.8.2               /usr/local/lib/python3.11/dist-packages uv
# PyOpenGL                           3.1.9               /usr/local/lib/python3.11/dist-packages uv
# pyOpenSSL                          24.2.1              /usr/local/lib/python3.11/dist-packages uv
# pyparsing                          3.2.1               /usr/local/lib/python3.11/dist-packages uv
# pyperclip                          1.9.0               /usr/local/lib/python3.11/dist-packages uv
# pyproj                             3.7.1               /usr/local/lib/python3.11/dist-packages uv
# pyshp                              2.3.1               /usr/local/lib/python3.11/dist-packages uv
# PySocks                            1.7.1               /usr/local/lib/python3.11/dist-packages uv
# pyspark                            3.5.4               /usr/local/lib/python3.11/dist-packages uv
# pytensor                           2.27.1              /usr/local/lib/python3.11/dist-packages uv
# pytest                             8.3.4               /usr/local/lib/python3.11/dist-packages uv
# python-apt                         0.0.0               /usr/local/lib/python3.11/dist-packages
# python-box                         7.3.2               /usr/local/lib/python3.11/dist-packages uv
# python-dateutil                    2.8.2               /usr/local/lib/python3.11/dist-packages uv
# python-dotenv                      1.0.1               /usr/local/lib/python3.11/dist-packages pip
# python-louvain                     0.16                /usr/local/lib/python3.11/dist-packages uv
# python-slugify                     8.0.4               /usr/local/lib/python3.11/dist-packages uv
# python-snappy                      0.7.3               /usr/local/lib/python3.11/dist-packages uv
# python-utils                       3.9.1               /usr/local/lib/python3.11/dist-packages uv
# pytz                               2025.1              /usr/local/lib/python3.11/dist-packages uv
# pyviz_comms                        3.0.4               /usr/local/lib/python3.11/dist-packages uv
# PyYAML                             6.0.2               /usr/local/lib/python3.11/dist-packages uv
# pyzmq                              24.0.1              /usr/local/lib/python3.11/dist-packages uv
# qdldl                              0.1.7.post5         /usr/local/lib/python3.11/dist-packages uv
# ratelim                            0.1.6               /usr/local/lib/python3.11/dist-packages uv
# referencing                        0.36.2              /usr/local/lib/python3.11/dist-packages uv
# regex                              2024.11.6           /usr/local/lib/python3.11/dist-packages uv
# requests                           2.32.3              /usr/local/lib/python3.11/dist-packages uv
# requests-oauthlib                  2.0.0               /usr/local/lib/python3.11/dist-packages uv
# requests-toolbelt                  1.0.0               /usr/local/lib/python3.11/dist-packages uv
# requirements-parser                0.9.0               /usr/local/lib/python3.11/dist-packages uv
# rich                               13.9.4              /usr/local/lib/python3.11/dist-packages uv
# rmm-cu12                           24.12.1             /usr/local/lib/python3.11/dist-packages uv
# rpds-py                            0.22.3              /usr/local/lib/python3.11/dist-packages uv
# rpy2                               3.4.2               /usr/local/lib/python3.11/dist-packages uv
# rsa                                4.9                 /usr/local/lib/python3.11/dist-packages uv
# safetensors                        0.5.2               /usr/local/lib/python3.11/dist-packages uv
# scikit-image                       0.25.2              /usr/local/lib/python3.11/dist-packages uv
# scikit-learn                       1.6.1               /usr/local/lib/python3.11/dist-packages uv
# scipy                              1.13.1              /usr/local/lib/python3.11/dist-packages uv
# scooby                             0.10.0              /usr/local/lib/python3.11/dist-packages uv
# scs                                3.2.7.post2         /usr/local/lib/python3.11/dist-packages uv
# seaborn                            0.13.2              /usr/local/lib/python3.11/dist-packages uv
# SecretStorage                      3.3.1               /usr/lib/python3/dist-packages
# Send2Trash                         1.8.3               /usr/local/lib/python3.11/dist-packages uv
# sentence-transformers              3.4.1               /usr/local/lib/python3.11/dist-packages uv
# sentencepiece                      0.2.0               /usr/local/lib/python3.11/dist-packages uv
# sentry-sdk                         2.22.0              /usr/local/lib/python3.11/dist-packages uv
# setproctitle                       1.3.4               /usr/local/lib/python3.11/dist-packages uv
# setuptools                         75.1.0              /usr/local/lib/python3.11/dist-packages uv
# shap                               0.46.0              /usr/local/lib/python3.11/dist-packages uv
# shapely                            2.0.7               /usr/local/lib/python3.11/dist-packages uv
# shellingham                        1.5.4               /usr/local/lib/python3.11/dist-packages uv
# simple-parsing                     0.1.7               /usr/local/lib/python3.11/dist-packages uv
# simsimd                            6.2.1               /usr/local/lib/python3.11/dist-packages uv
# six                                1.17.0              /usr/local/lib/python3.11/dist-packages uv
# sklearn-compat                     0.1.3               /usr/local/lib/python3.11/dist-packages uv
# sklearn-pandas                     2.2.0               /usr/local/lib/python3.11/dist-packages uv
# slicer                             0.0.8               /usr/local/lib/python3.11/dist-packages uv
# smart-open                         7.1.0               /usr/local/lib/python3.11/dist-packages uv
# smmap                              5.0.2               /usr/local/lib/python3.11/dist-packages uv
# sniffio                            1.3.1               /usr/local/lib/python3.11/dist-packages uv
# snowballstemmer                    2.2.0               /usr/local/lib/python3.11/dist-packages uv
# soundfile                          0.13.1              /usr/local/lib/python3.11/dist-packages uv
# soupsieve                          2.6                 /usr/local/lib/python3.11/dist-packages uv
# soxr                               0.5.0.post1         /usr/local/lib/python3.11/dist-packages uv
# spacy                              3.7.5               /usr/local/lib/python3.11/dist-packages uv
# spacy-legacy                       3.0.12              /usr/local/lib/python3.11/dist-packages uv
# spacy-loggers                      1.0.5               /usr/local/lib/python3.11/dist-packages uv
# spanner-graph-notebook             1.1.1               /usr/local/lib/python3.11/dist-packages uv
# Sphinx                             8.1.3               /usr/local/lib/python3.11/dist-packages uv
# sphinxcontrib-applehelp            2.0.0               /usr/local/lib/python3.11/dist-packages uv
# sphinxcontrib-devhelp              2.0.0               /usr/local/lib/python3.11/dist-packages uv
# sphinxcontrib-htmlhelp             2.1.0               /usr/local/lib/python3.11/dist-packages uv
# sphinxcontrib-jsmath               1.0.1               /usr/local/lib/python3.11/dist-packages uv
# sphinxcontrib-qthelp               2.0.0               /usr/local/lib/python3.11/dist-packages uv
# sphinxcontrib-serializinghtml      2.0.0               /usr/local/lib/python3.11/dist-packages uv
# SQLAlchemy                         2.0.38              /usr/local/lib/python3.11/dist-packages uv
# sqlglot                            25.6.1              /usr/local/lib/python3.11/dist-packages uv
# sqlparse                           0.5.3               /usr/local/lib/python3.11/dist-packages uv
# srsly                              2.5.1               /usr/local/lib/python3.11/dist-packages uv
# stanio                             0.5.1               /usr/local/lib/python3.11/dist-packages uv
# statsmodels                        0.14.4              /usr/local/lib/python3.11/dist-packages uv
# stringzilla                        3.11.3              /usr/local/lib/python3.11/dist-packages uv
# sympy                              1.13.1              /usr/local/lib/python3.11/dist-packages uv
# tables                             3.10.2              /usr/local/lib/python3.11/dist-packages uv
# tabulate                           0.9.0               /usr/local/lib/python3.11/dist-packages uv
# tbb                                2022.0.0            /usr/local/lib/python3.11/dist-packages uv
# tcmlib                             1.2.0               /usr/local/lib/python3.11/dist-packages uv
# tenacity                           9.0.0               /usr/local/lib/python3.11/dist-packages uv
# tensorboard                        2.18.0              /usr/local/lib/python3.11/dist-packages uv
# tensorboard-data-server            0.7.2               /usr/local/lib/python3.11/dist-packages uv
# tensorflow                         2.18.0              /usr/local/lib/python3.11/dist-packages uv
# tensorflow-datasets                4.9.7               /usr/local/lib/python3.11/dist-packages uv
# tensorflow-hub                     0.16.1              /usr/local/lib/python3.11/dist-packages uv
# tensorflow-io-gcs-filesystem       0.37.1              /usr/local/lib/python3.11/dist-packages uv
# tensorflow-metadata                1.16.1              /usr/local/lib/python3.11/dist-packages uv
# tensorflow-probability             0.25.0              /usr/local/lib/python3.11/dist-packages uv
# tensorflow-text                    2.18.1              /usr/local/lib/python3.11/dist-packages uv
# tensorstore                        0.1.71              /usr/local/lib/python3.11/dist-packages uv
# termcolor                          2.5.0               /usr/local/lib/python3.11/dist-packages uv
# terminado                          0.18.1              /usr/local/lib/python3.11/dist-packages uv
# text-unidecode                     1.3                 /usr/local/lib/python3.11/dist-packages uv
# textblob                           0.19.0              /usr/local/lib/python3.11/dist-packages uv
# tf_keras                           2.18.0              /usr/local/lib/python3.11/dist-packages uv
# tf-slim                            1.1.0               /usr/local/lib/python3.11/dist-packages uv
# thinc                              8.2.5               /usr/local/lib/python3.11/dist-packages uv
# threadpoolctl                      3.5.0               /usr/local/lib/python3.11/dist-packages uv
# tifffile                           2025.2.18           /usr/local/lib/python3.11/dist-packages uv
# tiktoken                           0.9.0               /usr/local/lib/python3.11/dist-packages pip
# timm                               1.0.14              /usr/local/lib/python3.11/dist-packages uv
# tinycss2                           1.4.0               /usr/local/lib/python3.11/dist-packages uv
# tokenizers                         0.21.0              /usr/local/lib/python3.11/dist-packages uv
# toml                               0.10.2              /usr/local/lib/python3.11/dist-packages uv
# toolz                              0.12.1              /usr/local/lib/python3.11/dist-packages uv
# torch                              2.5.1+cu124         /usr/local/lib/python3.11/dist-packages uv
# torchaudio                         2.5.1+cu124         /usr/local/lib/python3.11/dist-packages uv
# torchsummary                       1.5.1               /usr/local/lib/python3.11/dist-packages uv
# torchvision                        0.20.1+cu124        /usr/local/lib/python3.11/dist-packages uv
# tornado                            6.4.2               /usr/local/lib/python3.11/dist-packages uv
# tqdm                               4.67.1              /usr/local/lib/python3.11/dist-packages uv
# traitlets                          5.7.1               /usr/local/lib/python3.11/dist-packages uv
# traittypes                         0.2.1               /usr/local/lib/python3.11/dist-packages uv
# transformers                       4.48.3              /usr/local/lib/python3.11/dist-packages uv
# treescope                          0.1.9               /usr/local/lib/python3.11/dist-packages uv
# triton                             3.1.0               /usr/local/lib/python3.11/dist-packages uv
# tweepy                             4.15.0              /usr/local/lib/python3.11/dist-packages uv
# typeguard                          4.4.2               /usr/local/lib/python3.11/dist-packages uv
# typer                              0.15.1              /usr/local/lib/python3.11/dist-packages uv
# types-pytz                         2025.1.0.20250204   /usr/local/lib/python3.11/dist-packages uv
# types-setuptools                   75.8.0.20250210     /usr/local/lib/python3.11/dist-packages uv
# typing_extensions                  4.12.2              /usr/local/lib/python3.11/dist-packages uv
# typing-inspect                     0.9.0               /usr/local/lib/python3.11/dist-packages pip
# tzdata                             2025.1              /usr/local/lib/python3.11/dist-packages uv
# tzlocal                            5.3                 /usr/local/lib/python3.11/dist-packages uv
# uc-micro-py                        1.0.3               /usr/local/lib/python3.11/dist-packages uv
# umf                                0.9.1               /usr/local/lib/python3.11/dist-packages uv
# uritemplate                        4.1.1               /usr/local/lib/python3.11/dist-packages uv
# urllib3                            2.3.0               /usr/local/lib/python3.11/dist-packages uv
# vega-datasets                      0.9.0               /usr/local/lib/python3.11/dist-packages uv
# wadllib                            1.3.6               /usr/lib/python3/dist-packages
# wandb                              0.19.6              /usr/local/lib/python3.11/dist-packages uv
# wasabi                             1.1.3               /usr/local/lib/python3.11/dist-packages uv
# wcwidth                            0.2.13              /usr/local/lib/python3.11/dist-packages uv
# weasel                             0.4.1               /usr/local/lib/python3.11/dist-packages uv
# webcolors                          24.11.1             /usr/local/lib/python3.11/dist-packages uv
# webencodings                       0.5.1               /usr/local/lib/python3.11/dist-packages uv
# websocket-client                   1.8.0               /usr/local/lib/python3.11/dist-packages uv
# websockets                         14.2                /usr/local/lib/python3.11/dist-packages uv
# Werkzeug                           3.1.3               /usr/local/lib/python3.11/dist-packages uv
# wheel                              0.45.1              /usr/local/lib/python3.11/dist-packages uv
# widgetsnbextension                 3.6.10              /usr/local/lib/python3.11/dist-packages uv
# wordcloud                          1.9.4               /usr/local/lib/python3.11/dist-packages uv
# wrapt                              1.17.2              /usr/local/lib/python3.11/dist-packages uv
# xarray                             2025.1.2            /usr/local/lib/python3.11/dist-packages uv
# xarray-einstats                    0.8.0               /usr/local/lib/python3.11/dist-packages uv
# xgboost                            2.1.4               /usr/local/lib/python3.11/dist-packages uv
# xlrd                               2.0.1               /usr/local/lib/python3.11/dist-packages uv
# xyzservices                        2025.1.0            /usr/local/lib/python3.11/dist-packages uv
# yarl                               1.18.3              /usr/local/lib/python3.11/dist-packages uv
# yellowbrick                        1.5                 /usr/local/lib/python3.11/dist-packages uv
# yfinance                           0.2.54              /usr/local/lib/python3.11/dist-packages uv
# zipp                               3.21.0              /usr/local/lib/python3.11/dist-packages uv
# zstandard                          0.23.0              /usr/local/lib/python3.11/dist-packages uv

# %% [markdown]
# ### Install LangChain Packages
# Important to pin versions here to avoid issues with package updates.

# %%
# !pip install -qU langchain-openai==0.2.14 langchain_huggingface==0.1.2 langchain_core==0.3.28 langchain==0.3.13 langchain_community==0.3.13 langchain-text-splitters==0.3.4
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.6/411.6 kB 33.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 69.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.9/326.9 kB 24.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 56.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.6 MB/s eta 0:00:00

# %% [markdown]
# ### Install Other Packages
# Less worried about pinning versions for some other packages listed here, but still might be a good idea.

# %%
# !pip install -qU faiss-cpu python-pptx==1.0.2 nltk==3.9.1 pymupdf beautifulsoup4 lxml
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 25.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 67.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 95.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.1/165.1 kB 14.4 MB/s eta 0:00:00

# %% [markdown]
# ### Input OpenAI API Key
# This will be configured differently in the Chainlit app.

# %%
import os
import getpass

os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter Your OpenAI API Key: ")
# Out:
# Enter Your OpenAI API Key: ··········

# %% [markdown]
# ### Create Data Directory
# Will be used to store documents for fine-tuning and evaluation. Documents are uploaded manually for now and include a subset of the funding opportunities listed on NIH's website: https://grants.nih.gov/funding/nih-guide-for-grants-and-contracts

# %%
# !mkdir data
# !mkdir data/Opportunities

# %% [markdown]
# ### Retrieve Opportunity Details

# %%
import pandas
import subprocess

# Limit opportunity count
opportunity_count = 100

# Path to the CSV file
csv_file_path = "data/Opportunities/NIH_Funding_Opportunities_20250221.csv"

# Load the CSV data into a DataFrame
df = pandas.read_csv(csv_file_path)

# Extract the html files 
counter = 0

for index, row in df.iterrows():
    output_file = "data/Opportunities/" + row['Document_Number'] + ".html"
    # Construct the curl command
    curl_command = [
        "curl",
        "-X", "GET",  # or "POST", "PUT", etc.
        row['URL'],
        "-o", output_file
    ]
    
    # Execute the curl command
    try:
        result = subprocess.run(curl_command, check=True, text=True, capture_output=True)
    except subprocess.CalledProcessError as e:
        print("An error occurred:", e)
        
    counter += 1
    
    # Limit to opportunity count
    if counter > opportunity_count:
        break

# %% [markdown]
# ### Split Documents Using HTML Section Splitter from LangChain
# Splits documents by header tags.

# %%
from langchain_text_splitters import HTMLSectionSplitter

headers_to_split_on = [("h1", "Header 1"), ("h2", "Header 2"), ("h3", "Header 3")]

html_splitter = HTMLSectionSplitter(
    headers_to_split_on=headers_to_split_on
)

# %% [markdown]
# ### Clean HTML Documents and Add to Opportunities List
# Removes extraneous code and adds metadata to header tags to make retrieval process potentially more accurate for this specific use case.

# %%
from bs4 import BeautifulSoup
import fnmatch
import pprint

# Path to the directory containing HTML files
directory_path = "data/Opportunities"

def clean_html(html_raw):
    soup = BeautifulSoup(html_raw.replace("\n", "").replace("\t", ""), 'html.parser')
    # Remove div tags (could use some more work)
    for div_tag in soup.find_all('div'):
        div_tag.replaceWithChildren()
    # Remove script tags 
    for script in soup.find_all('script'):
        script.decompose()
    # Remove title tags
    for title in soup.find_all('title'):
        opportunity_title = title.string
        title.decompose()
    # Remove meta tags 
    for meta in soup.find_all('meta'):
        meta.decompose()
    # Add metadata to header tags 
    for header in soup.find_all(['h1', 'h2', 'h3']):
        if header.string is not None:
            header.string.replace_with(f"{opportunity_title} {header.string}")
    # Return clean file
    return soup.prettify() 

# Initialize opportunities document list
training_opportunities = []

# Iterate over each file in the directory
for filename in os.listdir(directory_path):
    # Check if the file is an HTML file
    if fnmatch.fnmatch(filename, '*.html'):
        file_path = os.path.join(directory_path, filename)
        #Read html file
        with open(file_path, 'r') as f:
            html_raw = f.read()
        #Add cleaned and chunked html file to opportunities list
        training_opportunities.extend(html_splitter.split_text(clean_html(html_raw)))

# Add metadata to page content
for row in training_opportunities:
    if 'Header 1' in row.metadata:
        row.page_content = row.metadata['Header 1'] + ' ' + row.page_content
    elif 'Header 2' in row.metadata:
        row.page_content = row.metadata['Header 2'] + ' ' + row.page_content
    elif 'Header 3' in row.metadata:
        row.page_content = row.metadata['Header 3'] + ' ' + row.page_content

# Remove #TITLE# rows
training_opportunities = [doc for doc in training_opportunities if doc.metadata.get('Header 1') != '#TITLE#']

len(training_opportunities)
pprint.pprint(training_opportunities[0:10])
# Out:
# <ipython-input-10-5ecbb4559cfa>:12: DeprecationWarning: Call to deprecated method replaceWithChildren. (Replaced by unwrap) -- Deprecated since version 4.0.0.
#   div_tag.replaceWithChildren()

# %% [markdown]
# ### Add Unique Ids
# Add unique ids to training opportunities list to facilitate fine-tuning process later.

# %%
import uuid

id_set = set()

for document in training_opportunities:
  id = str(uuid.uuid4())
  while id in id_set:
    id = uuid.uuid4()
  id_set.add(id)
  document.metadata["id"] = id

# %% [markdown]
# ### Split Opportunities List into Training, Validation, and Test Lists
# The training list will be used to fine-tune the model, the validation list will be used to validate it, and the test list will remain untouched in the fine-tuning process but later used in the evalution process.

# %%
training_size = len(training_opportunities)*.7
validation_test_size = len(training_opportunities)*.15

training_split_documents = training_opportunities[:training_size]
val_split_documents = training_opportunities[training_size+1:training_size+1+validation_test_size]
test_split_documents = training_opportunities[training_size+2+validation_test_size:]

# %% [markdown]
# ### Initialize Chat Model to Generate Questions

# %%
from langchain_openai import ChatOpenAI

qa_chat_model = ChatOpenAI(
    model="gpt-4o",
    temperature=0
)

# %% [markdown]
# ### Create Prompt Template for Generating Questions
# This remains unchanged from what we used in class and is simply using the gpt-4o-mini model to generate question/context pairs from the provided questions.

# %%
from langchain_core.prompts import ChatPromptTemplate

qa_prompt = """\
Given the following context, you must generate project complexities A.K.A. questions using the following guidelines.
1) Regulatory: (High/Medium/Low) - Rank proportionately to the number of regulations required. Provide examples supporting the score.
2) Data Collection and Management: (High/Medium/Low) - Rank proportionately to number of data elements needed (per participating site), data complexity, data sensitivity, and data collection frequency. Rank higher for more participating sites. Provide examples supporting the score.
3) Statistical Analysis and Manuscript Development: (High/Medium/Low) - Estimate the level of statistical analysis involved. Rank non-standard processes higher than standard ones. Provide examples supporting the score.
4) Information Technology: (High/Medium/Low) - Rank proportionately to IT monitoring and maintenance, software licenses and subscriptions. Rank routine services lower than non-standard services. Provide examples supporting the score.
5) Operational: (High/Medium/Low) - Rank proportionately to project administration effort required and increased site onboarding, coordination and training. Provide examples supporting the score.
6) Financial: (High/Medium/Low) - Rank proportionately to budget management complexity. Provide examples supporting the score.

You are to generate {n_questions} questions which should be provided in the following format:

1. QUESTION #1
2. QUESTION #2
...

Context:
{context}
"""

qa_prompt_template = ChatPromptTemplate.from_template(qa_prompt)

# %% [markdown]
# ### Create LCEL Chain for Generating Questions
# We're going to invoke this chain for each of the provided document lists.

# %%
question_generation_chain = qa_prompt_template | qa_chat_model

# %% [markdown]
# ### Define Function to Create Questions
# We need to define a function that will return all of the generated question/context pairs per document.

# %%
import tqdm

async def create_questions(documents, n_questions):
  questions = {}
  relevant_docs = {}

  for document in tqdm.tqdm(documents):
    document_content = {"context" : document.page_content, "questions" : []}
    questions_generated = question_generation_chain.invoke({"context": document.page_content, "n_questions": n_questions})
    for question in questions_generated.content.split("\n"):
      question_id = str(uuid.uuid4())
      questions[question_id] = "".join(question.split(".")[1:]).strip()
      relevant_docs[question_id] = [document.metadata["id"]]
  return questions, relevant_docs

  await questions, relevant_docs

# %% [markdown]
# ### Create Training, Validation and Test Questions
# This section is simply calling the create_questions function for each of the document lists.

# %%
training_questions, training_relevant_contexts = await create_questions(training_split_documents, 10)
# Out:
# 100%|██████████| 108/108 [02:04<00:00,  1.15s/it]

# %%
val_questions, val_relevant_contexts = await create_questions(val_split_documents, 10)
# Out:
# 100%|██████████| 12/12 [00:13<00:00,  1.13s/it]

# %%
test_questions, test_relevant_contexts = await create_questions(test_split_documents, 10)
# Out:
# 100%|██████████| 12/12 [00:14<00:00,  1.21s/it]

# %% [markdown]
# ### Modfiy Format of Training, Validation and Test Questions
# We need to modify the question/context lists to be in a format we can use for the fine-tuning process.

# %%
import json

training_corpus = {train_item.metadata["id"] : train_item.page_content for train_item in training_split_documents}

train_dataset = {
    "questions" : training_questions,
    "relevant_contexts" : training_relevant_contexts,
    "corpus" : training_corpus
}

with open("training_dataset.jsonl", "w") as f:
  json.dump(train_dataset, f)

# %%
val_corpus = {val_item.metadata["id"] : val_item.page_content for val_item in val_split_documents}

val_dataset = {
    "questions" : val_questions,
    "relevant_contexts" : val_relevant_contexts,
    "corpus" : val_corpus
}

with open("val_dataset.jsonl", "w") as f:
  json.dump(val_dataset, f)

# %%
train_corpus = {test_item.metadata["id"] : test_item.page_content for test_item in test_split_documents}

test_dataset = {
    "questions" : test_questions,
    "relevant_contexts" : test_relevant_contexts,
    "corpus" : train_corpus
}

with open("test_dataset.jsonl", "w") as f:
  json.dump(test_dataset, f)

# %% [markdown]
# ### Install Dependencies for Fine-Tuning Process

# %%
# !pip install -qU sentence_transformers==3.3.1 datasets pyarrow==18.1.0 fsspec==2024.10.0
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 17.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 MB 52.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 37.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 16.3 MB/s eta 0:00:00

# %% [markdown]
# ### Download Embedding Model
# I tried some different models here and ran into issues with memory and newer model configurations that didn't seem to be supported by the package and Python configurations in this notebook. So, I stuck with the default model used in class.

# %%
from sentence_transformers import SentenceTransformer

model_id = "Snowflake/snowflake-arctic-embed-l"
model = SentenceTransformer(model_id)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/85.4k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/107 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/704 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/297 [00:00<?, ?B/s]

# %% [markdown]
# ### Import Dependencies for Fine-Tuning Process

# %%
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from sentence_transformers import InputExample

# %% [markdown]
# ### Configure Batches

# %%
BATCH_SIZE = 10

# %% [markdown]
# ### Configure Examples

# %%
corpus = train_dataset['corpus']
queries = train_dataset['questions']
relevant_docs = train_dataset['relevant_contexts']

examples = []
for query_id, query in queries.items():
    doc_id = relevant_docs[query_id][0]
    text = corpus[doc_id]
    example = InputExample(texts=[query, text])
    examples.append(example)

# %% [markdown]
# ### Load Examples

# %%
loader = DataLoader(
    examples, batch_size=BATCH_SIZE
)

# %% [markdown]
# ### Define Loss Function
# Remains unchanged from what we used in class as this has been established as a fairly effective and flexible approach.

# %%
from sentence_transformers.losses import MatryoshkaLoss, MultipleNegativesRankingLoss

matryoshka_dimensions = [768, 512, 256, 128, 64]
inner_train_loss = MultipleNegativesRankingLoss(model)
train_loss = MatryoshkaLoss(
    model, inner_train_loss, matryoshka_dims=matryoshka_dimensions
)

# %% [markdown]
# ### Initialize Evaluator

# %%
from sentence_transformers.evaluation import InformationRetrievalEvaluator

corpus = val_dataset['corpus']
queries = val_dataset['questions']
relevant_docs = val_dataset['relevant_contexts']

evaluator = InformationRetrievalEvaluator(queries, corpus, relevant_docs)

# %% [markdown]
# ### Configure Epochs

# %%
EPOCHS = 10

# %% [markdown]
# ### Fine-Tune Model Using Configurations Defined Above

# %%
import wandb
wandb.init(mode="disabled")
# Out:
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/dummy/dummy/runs/8bx274nr?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
warmup_steps = int(len(loader) * EPOCHS * 0.1)

model.fit(
    train_objectives=[(loader, train_loss)],
    epochs=EPOCHS,
    warmup_steps=warmup_steps,
    output_path='finetuned_arctic_ft',
    show_progress_bar=True,
    evaluator=evaluator,
    evaluation_steps=50
)
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
#     <div>
#
#       <progress value='220' max='220' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [220/220 02:55, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Cosine Accuracy@1</th>
#       <th>Cosine Accuracy@3</th>
#       <th>Cosine Accuracy@5</th>
#       <th>Cosine Accuracy@10</th>
#       <th>Cosine Precision@1</th>
#       <th>Cosine Precision@3</th>
#       <th>Cosine Precision@5</th>
#       <th>Cosine Precision@10</th>
#       <th>Cosine Recall@1</th>
#       <th>Cosine Recall@3</th>
#       <th>Cosine Recall@5</th>
#       <th>Cosine Recall@10</th>
#       <th>Cosine Ndcg@10</th>
#       <th>Cosine Mrr@10</th>
#       <th>Cosine Map@100</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>22</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.750000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.750000</td>
#       <td>0.333333</td>
#       <td>0.200000</td>
#       <td>0.100000</td>
#       <td>0.750000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.902277</td>
#       <td>0.868056</td>
#       <td>0.868056</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.875000</td>
#       <td>0.958333</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.875000</td>
#       <td>0.319444</td>
#       <td>0.200000</td>
#       <td>0.100000</td>
#       <td>0.875000</td>
#       <td>0.958333</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.945522</td>
#       <td>0.927083</td>
#       <td>0.927083</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.916667</td>
#       <td>0.958333</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.916667</td>
#       <td>0.319444</td>
#       <td>0.200000</td>
#       <td>0.100000</td>
#       <td>0.916667</td>
#       <td>0.958333</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.960900</td>
#       <td>0.947917</td>
#       <td>0.947917</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.916667</td>
#       <td>0.958333</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.916667</td>
#       <td>0.319444</td>
#       <td>0.200000</td>
#       <td>0.100000</td>
#       <td>0.916667</td>
#       <td>0.958333</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.960900</td>
#       <td>0.947917</td>
#       <td>0.947917</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.916667</td>
#       <td>0.333333</td>
#       <td>0.200000</td>
#       <td>0.100000</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.969244</td>
#       <td>0.958333</td>
#       <td>0.958333</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.916667</td>
#       <td>0.333333</td>
#       <td>0.200000</td>
#       <td>0.100000</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.969244</td>
#       <td>0.958333</td>
#       <td>0.958333</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.916667</td>
#       <td>0.333333</td>
#       <td>0.200000</td>
#       <td>0.100000</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.969244</td>
#       <td>0.958333</td>
#       <td>0.958333</td>
#     </tr>
#     <tr>
#       <td>132</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.916667</td>
#       <td>0.333333</td>
#       <td>0.200000</td>
#       <td>0.100000</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.969244</td>
#       <td>0.958333</td>
#       <td>0.958333</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.916667</td>
#       <td>0.333333</td>
#       <td>0.200000</td>
#       <td>0.100000</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.969244</td>
#       <td>0.958333</td>
#       <td>0.958333</td>
#     </tr>
#     <tr>
#       <td>154</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.916667</td>
#       <td>0.333333</td>
#       <td>0.200000</td>
#       <td>0.100000</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.969244</td>
#       <td>0.958333</td>
#       <td>0.958333</td>
#     </tr>
#     <tr>
#       <td>176</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.916667</td>
#       <td>0.333333</td>
#       <td>0.200000</td>
#       <td>0.100000</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.963789</td>
#       <td>0.951389</td>
#       <td>0.951389</td>
#     </tr>
#     <tr>
#       <td>198</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.916667</td>
#       <td>0.333333</td>
#       <td>0.200000</td>
#       <td>0.100000</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.969244</td>
#       <td>0.958333</td>
#       <td>0.958333</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.916667</td>
#       <td>0.333333</td>
#       <td>0.200000</td>
#       <td>0.100000</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.969244</td>
#       <td>0.958333</td>
#       <td>0.958333</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>No log</td>
#       <td>No log</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.916667</td>
#       <td>0.333333</td>
#       <td>0.200000</td>
#       <td>0.100000</td>
#       <td>0.916667</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.969244</td>
#       <td>0.958333</td>
#       <td>0.958333</td>
#     </tr>
#   </tbody>
# </table><p>
# Computing widget examples:   0%|          | 0/1 [00:00<?, ?example/s]

# %% [markdown]
# ### Upload Fine-Tuned Model to Hugging Face

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
hf_username = "christinemahler"

# %%
model.push_to_hub(f"{hf_username}/aie5-midterm")
# Out:
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# 'https://huggingface.co/christinemahler/aie5-midterm/commit/4f0e02dc5284a02b16d26cfbc7ff678140d66c96'

# %% [markdown]
# ### Define Evaluate Function
# We are simply evaluating the hit rates for a few different embedding models. This is where the document ids come in handy.

# %%
import pandas as pd

from langchain_community.vectorstores import FAISS
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain_core.documents import Document

# %%
def evaluate_openai(
    dataset,
    embed_model,
    top_k=5,
    verbose=False,
):
  corpus = dataset['corpus']
  questions = dataset['questions']
  relevant_docs = dataset['relevant_contexts']
  documents = [Document(page_content=content, metadata={"id": doc_id}) for doc_id, content in corpus.items()]
  vectorstore = FAISS.from_documents(documents, embed_model)

  retriever = vectorstore.as_retriever(search_kwargs={"k": top_k})

  eval_results = []
  for id, question in tqdm.tqdm(questions.items()):
    retrieved_nodes = retriever.invoke(question)
    retrieved_ids = [node.metadata["id"] for node in retrieved_nodes]
    expected_id = relevant_docs[id][0]
    is_hit = expected_id in retrieved_ids
    eval_results.append({"id": id, "question": question, "expected_id": expected_id, "is_hit": is_hit})

  return eval_results

# %% [markdown]
# ### Evaluate Hits Against text-embedding-3-small Model
# This embedding model scores well (87.5%) but not perfect.

# %%
te3_openai = OpenAIEmbeddings(model="text-embedding-3-small")
te3_results = evaluate_openai(test_dataset, te3_openai)
# Out:
# 100%|██████████| 24/24 [00:13<00:00,  1.83it/s]

# %%
te3_results_df = pd.DataFrame(te3_results)

# %%
te3_hit_rate = te3_results_df["is_hit"].mean()
te3_hit_rate
# Out:
# 0.875

# %% [markdown]
# ### Evaluate Hits Against Snowflake/snowflake-arctic-embed-l Model
# This model does not score as well (79.2%) as the OpenAI model.

# %%
from langchain_huggingface import HuggingFaceEmbeddings

huggingface_embeddings = HuggingFaceEmbeddings(model_name="Snowflake/snowflake-arctic-embed-l")
arctic_embed_m_results = evaluate_openai(test_dataset, huggingface_embeddings)
# Out:
# 100%|██████████| 24/24 [00:00<00:00, 48.63it/s]

# %%
arctic_embed_m_results_df = pd.DataFrame(arctic_embed_m_results)

# %%
arctic_embed_m_hit_rate = arctic_embed_m_results_df["is_hit"].mean()
arctic_embed_m_hit_rate
# Out:
# 0.7916666666666666

# %% [markdown]
# ### Evaluate Hits Against Fine-Tuned Model
# This model now scores 100% suggesting that the fine-tuning process was effective.

# %%
finetune_embeddings = HuggingFaceEmbeddings(model_name="christinemahler/aie5-midterm")
finetune_results = evaluate_openai(test_dataset, finetune_embeddings)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/290k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/641 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of BertModel were not initialized from the model checkpoint at christinemahler/aie5-midterm and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/1.41k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/297 [00:00<?, ?B/s]
# 100%|██████████| 24/24 [00:00<00:00, 48.45it/s]

# %%
finetune_results_df = pd.DataFrame(finetune_results)

# %%
finetune_hit_rate = finetune_results_df["is_hit"].mean()
finetune_hit_rate
# Out:
# 1.0

# %% [markdown]
# ### Load Opportunities Chunks into Vector Store Using Base Embeddings
# For now evaluating our RAG process using the different embeddings.

# %%
from langchain_community.vectorstores import FAISS

base_vectorstore = FAISS.from_documents(training_opportunities, huggingface_embeddings)
base_retriever = base_vectorstore.as_retriever(search_kwargs={"k": 6})

# %% [markdown]
# ### Create Prompt Template for Chat Model
# This template has been tweaked for the specific use case of assessing a study's complexity using the provided funding opportunity info.

# %%
from langchain_core.prompts import ChatPromptTemplate

RAG_PROMPT = """\
Use the provided context to answer the user's question. Only use the provided context to answer the question.

If the user asks you to evaluate the study complexity, provide a complexity score of high, medium, or low and a reason for all of the following categories:
1) Regulatory and Compliance (rank higher if study requires compliance with multiple regulations and provide examples)
2) Data Collection and Management (identify data elements needed, data complexity, data sensitivity, and data collection frequency)
3) Statistical Analysis and Manuscript Development (provide examples)
4) Information Technology (identify data collection services and equipment needed along with software licenses and subscriptions)
5) Operational (includes project administration and site onboarding, coordination and training)
6) Financial (includes budget management and effort allocation over entire duration of project; rank higher if more resources are required)

If you do not know the answer, or it's not contained in the provided context response with "I don't know"

Context:
{context}

Question:
{question}
"""

rag_prompt_template = ChatPromptTemplate.from_template(RAG_PROMPT)

# %% [markdown]
# ### Initialize RAG Chat Model
# Will be used for both RAG chains.

# %%
rag_llm =  ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0
)

# %% [markdown]
# ### Create Base RAG LCEL Chain

# %%
from operator import itemgetter
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough, RunnableParallel

base_rag_chain = (
    {"context": itemgetter("question") | base_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt_template | rag_llm | StrOutputParser(), "context": itemgetter("context")}
)

# %% [markdown]
# ### Vibe Check Base RAG Chain Output
# An increased number of "I don't know" responses may perhaps demonstrate a less effective embedding, although the prompt template and selected chat model may also be a factor.

# %%
import pprint

pprint.pprint(base_rag_chain.invoke({"question" : "evaluate the study complexity of the PAR-25-353 funding opportunity"})["response"])
# Out:
# "I don't know"

# %%
pprint.pprint(base_rag_chain.invoke({"question" : "What is NCDDG?"})["response"])
# Out:
# "I don't know."

# %%
pprint.pprint(base_rag_chain.invoke({"question" : "Summarize PAR-25-353 funding opportunity"})["response"])
# Out:
# "I don't know."

# %% [markdown]
# ### Load Opportunities Chunks into Vector Store Using Fine-Tuned Embeddings
# Load opportunities now using our fine-tuned embeddings.

# %%
finetune_vectorstore = FAISS.from_documents(training_opportunities, finetune_embeddings)
finetune_retriever = finetune_vectorstore.as_retriever(search_kwargs={"k": 6})

# %% [markdown]
# ### Create Fine-Tuned RAG LCEL Chain

# %%
finetune_rag_chain = (
    {"context": itemgetter("question") | finetune_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt_template | rag_llm | StrOutputParser(), "context": itemgetter("context")}
)

# %% [markdown]
# ### Vibe Check Fine-Tuned RAG Chain Output
# We should see improved responses from the chat model in this case, and that is indeed what we see in this case.

# %%
pprint.pprint(finetune_rag_chain.invoke({"question" : "evaluate the study complexity of the PAR-25-353 funding opportunity"})["response"])
# Out:
# ('1) Regulatory and Compliance: **High**  \n'
#  'The study involves compliance with NIH grants policies and potentially '
#  'multiple regulations related to clinical trials, such as the Investigational '
#  'New Drug (IND) and Investigational Device Exemption (IDE) requirements. The '
#  'substantial involvement of NIH scientific or program staff also adds to the '
#  'regulatory complexity.\n'
#  '\n'
#  '2) Data Collection and Management: **Medium**  \n'
#  'The study will likely require the collection of sensitive data related to '
#  'mental health disorders, including patient demographics, treatment '
#  'responses, and safety assessments. The complexity arises from the need for '
#  'rigorous data management practices, but specific data elements and '
#  'collection frequency are not detailed in the context.\n'
#  '\n'
#  '3) Statistical Analysis and Manuscript Development: **Medium**  \n'
#  'The study will require statistical analysis to assess the safety, '
#  'tolerability, and pharmacodynamics of drug candidates/devices. The '
#  'development of manuscripts for publication will also be necessary, which can '
#  'be complex but is standard in clinical research.\n'
#  '\n'
#  '4) Information Technology: **Medium**  \n'
#  'The study may require data collection services and equipment for clinical '
#  'trials, as well as software for data management and analysis. However, '
#  'specific software licenses and subscriptions are not mentioned in the '
#  'context.\n'
#  '\n'
#  '5) Operational: **High**  \n'
#  'The operational complexity is high due to the need for project '
#  'administration, site onboarding, coordination, and training of personnel '
#  'involved in the study. The multidisciplinary approach and potential '
#  'partnerships between academia and industry further complicate operations.\n'
#  '\n'
#  '6) Financial: **Medium**  \n'
#  'While application budgets are not limited, they must reflect the actual '
#  'needs of the project, which can vary significantly. The complexity is medium '
#  'as it requires careful budget management and effort allocation, but the '
#  'absence of strict budget caps allows for flexibility.')

# %%
pprint.pprint(finetune_rag_chain.invoke({"question" : "What is NCDDG?"})["response"])
# Out:
# ('NCDDG stands for National Cooperative Drug/Device Discovery/Development '
#  'Groups. It is a program intended to encourage applications from academic, '
#  'biotechnology, biomedical device industry, or pharmaceutical industry '
#  'investigators to collaborate with the National Institute of Mental Health '
#  '(NIMH). The objectives of the NCDDG program include advancing the discovery, '
#  'preclinical development, early-stage human studies, and proof of concept '
#  'testing of new candidate agents or devices to treat mental disorders, as '
#  'well as developing novel ligands and brain circuit-modulatory technologies '
#  'for biological research related to mental disorders. The program emphasizes '
#  'partnerships between academia and industry to facilitate the development of '
#  'new therapeutics and research tools.')

# %%
pprint.pprint(finetune_rag_chain.invoke({"question" : "Summarize PAR-25-353 funding opportunity"})["response"])
# Out:
# ('The PAR-25-353 funding opportunity, titled "National Cooperative Drug/Device '
#  'Discovery/Development Groups (NCDDG) for the Treatment of Mental Disorders '
#  '(U19 Clinical Trial Optional)," is issued by the National Institutes of '
#  'Health (NIH) and specifically involves the National Institute of Mental '
#  'Health (NIMH). The purpose of this funding opportunity is to accelerate '
#  'innovative drug and device discovery, develop pharmacologic and '
#  'neuromodulatory tools for research on mental health, and support early-stage '
#  'human studies to assess the safety, tolerability, and pharmacodynamics of '
#  'promising drug candidates and devices for treating mental disorders.\n'
#  '\n'
#  'This funding opportunity encourages multidisciplinary partnerships between '
#  'academia and industry and supports a research program consisting of multiple '
#  'projects directed toward a specific major objective or theme. It allows for '
#  'applications proposing preclinical discovery of biotechnology products and '
#  'biologics, including large biologic macromolecules, gene-based therapies, '
#  'and novel emerging therapies.\n'
#  '\n'
#  'The funding instrument is a cooperative agreement, indicating substantial '
#  'federal involvement in the project. Applications can be new, renewals, '
#  'resubmissions, or revisions, and the total project period may not exceed '
#  'five years. There are no specific budget limits, but the application budgets '
#  'must reflect the actual needs of the proposed project.')

# %% [markdown]
# ### Install Ragas Dependencies
# Now we'll use the Ragas framework to more systematically evaluate the performance of our new embeddings.

# %%
# !pip install -qU ragas==0.2.10 rapidfuzz==3.12.1
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.7/175.7 kB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 90.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 6.5 MB/s eta 0:00:00

# %% [markdown]
# ### Import RAGAS Dependencies and Initialize Evaluator Objects

# %%
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
generator_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4o"))
generator_embeddings = LangchainEmbeddingsWrapper(OpenAIEmbeddings())

# %% [markdown]
# ### Generate Test Data Using RAGAS
# We need to generate some test data to run through our different RAG chains. We can either do this manually (the less fun way) or else systematically using the Ragas TestsetGenerator.

# %%
from ragas.testset import TestsetGenerator

generator = TestsetGenerator(llm=generator_llm, embedding_model=generator_embeddings)
dataset = generator.generate_with_langchain_docs(training_opportunities, testset_size=10)
# Out:
# Applying HeadlinesExtractor:   0%|          | 0/84 [00:00<?, ?it/s]
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Request too large for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Requested 42997. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29474, Requested 8490. Please try again in 15.928s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29140, Requested 9135. Please try again in 16.55s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29647, Requested 10418. Please try again in 20.13s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Applying HeadlineSplitter:   0%|          | 0/132 [00:00<?, ?it/s]
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: 'headlines' property not found in this node
# Applying SummaryExtractor:   0%|          | 0/106 [00:00<?, ?it/s]
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 24256, Requested 7919. Please try again in 4.35s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '367947'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '6b4bf9'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '60741b'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node 'e34cb4'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '942ff5'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '4be45b'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '5dd6bd'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '0e7584'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '1979e1'. Skipping!
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Request too large for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Requested 42869. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '9e195c'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '31bc18'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '7eeca8'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node 'af90d0'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node 'a2de7b'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '8e47a5'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '5646cd'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '71a070'. Skipping!
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29489, Requested 8362. Please try again in 15.702s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '716f34'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '8f76da'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node 'b72587'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '0fd2c2'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary' already exists in node '3a2c22'. Skipping!
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 26501, Requested 10890. Please try again in 14.782s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 27724, Requested 9008. Please try again in 13.464s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28315, Requested 11637. Please try again in 19.904s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Applying CustomNodeFilter:   0%|          | 0/221 [00:00<?, ?it/s]
# WARNING:ragas.testset.transforms.filters:Node 7f50bf60-3d24-49e2-a208-ddcaf110cb61 does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node 25819912-c209-4eb5-8f38-4ffffab70893 does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node 037b6bfe-b89c-40bc-a4b8-f1612442b013 does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node 3a46fd19-271e-4e1e-87e2-32582f12f980 does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node 72e930b8-166a-4ff4-924b-21507a8907d9 does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node 49d98fad-c504-4c8e-9c20-2c98c5aa18c5 does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node 6f64eac1-00fa-432d-93d6-477b08610ac4 does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node 87ead985-1779-4c12-bcea-c016981b2d8d does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node 9f418df0-b4af-4a56-b995-2f1eac55b51b does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node 96a09e30-3287-4756-b360-7a2e257161b3 does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node a33e88e9-3ebf-4e76-832a-941a5e66c1b2 does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node 3ba185f8-898c-4471-948d-ab4930abc6e3 does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node a188fea7-e2e7-4d57-9cf2-4cd18aeccd15 does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node bf06bad4-b396-4d98-acd2-da876a88fd49 does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node 50376efc-b13a-4d2a-b264-0ec0fc43edb0 does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node 715920db-f62c-4f4c-991a-fc64f3690513 does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node 8cc19871-50ff-4d48-88c6-a935d8360cfd does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node cb4f9e92-97b1-4421-a142-68e50261b561 does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node b4c88773-d69b-46c7-a25c-8b93cf5e1f57 does not have a summary. Skipping filtering.
# WARNING:ragas.testset.transforms.filters:Node 38590110-475b-4eb9-800d-dabb285fdcc2 does not have a summary. Skipping filtering.
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28568, Requested 2347. Please try again in 1.83s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28542, Requested 2378. Please try again in 1.84s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28472, Requested 2437. Please try again in 1.818s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29817, Requested 2430. Please try again in 4.494s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28691, Requested 2384. Please try again in 2.15s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28493, Requested 2378. Please try again in 1.742s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28600, Requested 2324. Please try again in 1.848s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29678, Requested 2514. Please try again in 4.384s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28991, Requested 2398. Please try again in 2.778s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28688, Requested 2393. Please try again in 2.162s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29059, Requested 2390. Please try again in 2.898s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28909, Requested 2353. Please try again in 2.524s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28794, Requested 2321. Please try again in 2.23s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28534, Requested 2369. Please try again in 1.806s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28401, Requested 2446. Please try again in 1.694s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28535, Requested 2425. Please try again in 1.92s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Applying [EmbeddingExtractor, ThemesExtractor, NERExtractor]:   0%|          | 0/536 [00:00<?, ?it/s]
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '367947'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '6b4bf9'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '60741b'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node 'e34cb4'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '942ff5'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '4be45b'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '5dd6bd'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '0e7584'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '1979e1'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '9e195c'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '7eeca8'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '31bc18'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node 'a2de7b'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node 'af90d0'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '8e47a5'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '5646cd'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '71a070'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '716f34'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '8f76da'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node 'b72587'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '0fd2c2'. Skipping!
# WARNING:ragas.testset.transforms.base:Property 'summary_embedding' already exists in node '3a2c22'. Skipping!
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29590, Requested 2100. Please try again in 3.38s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28077, Requested 2144. Please try again in 442ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29868, Requested 1984. Please try again in 3.704s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29091, Requested 2050. Please try again in 2.282s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29004, Requested 1945. Please try again in 1.898s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29797, Requested 2112. Please try again in 3.818s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29202, Requested 1988. Please try again in 2.38s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28943, Requested 2085. Please try again in 2.056s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29100, Requested 2120. Please try again in 2.44s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28902, Requested 2045. Please try again in 1.894s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28343, Requested 1997. Please try again in 680ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29124, Requested 2034. Please try again in 2.316s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28538, Requested 2029. Please try again in 1.134s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29466, Requested 2085. Please try again in 3.102s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28938, Requested 2013. Please try again in 1.902s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29220, Requested 2054. Please try again in 2.548s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29714, Requested 1978. Please try again in 3.384s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29627, Requested 2041. Please try again in 3.336s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29811, Requested 1706. Please try again in 3.034s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28052, Requested 2057. Please try again in 218ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29295, Requested 2050. Please try again in 2.69s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29041, Requested 2060. Please try again in 2.202s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29506, Requested 2120. Please try again in 3.252s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29692, Requested 2126. Please try again in 3.636s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29673, Requested 2115. Please try again in 3.576s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28937, Requested 2084. Please try again in 2.042s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28910, Requested 1983. Please try again in 1.786s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28744, Requested 2024. Please try again in 1.536s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29080, Requested 2146. Please try again in 2.452s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29154, Requested 2117. Please try again in 2.542s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29484, Requested 1982. Please try again in 2.932s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29427, Requested 2066. Please try again in 2.986s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28867, Requested 2137. Please try again in 2.008s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28658, Requested 2096. Please try again in 1.508s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29334, Requested 2062. Please try again in 2.792s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29752, Requested 2102. Please try again in 3.708s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29175, Requested 2058. Please try again in 2.466s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29196, Requested 2132. Please try again in 2.656s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29479, Requested 1956. Please try again in 2.87s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29492, Requested 2071. Please try again in 3.126s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 28367, Requested 2046. Please try again in 826ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29490, Requested 2077. Please try again in 3.134s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Applying [CosineSimilarityBuilder, OverlapScoreBuilder]:   0%|          | 0/2 [00:00<?, ?it/s]
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Node a80a8972-3c91-4fb5-a1c4-68fcdb31ac36 has no summary_embedding
# ERROR:ragas.testset.transforms.engine:unable to apply transformation: Node 6cf58aa1-d18b-4e3d-ad7c-cfb37672c403 or 856ec340-be6e-4506-b125-e39429742a59 has no entities
# Generating personas:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating Scenarios:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating Samples:   0%|          | 0/10 [00:00<?, ?it/s]

# %%
dataset.to_pandas()
# Out:
#                                           user_input  \
# 0  How can a neuroscientist and drug developer su...
# 1  What are the objectives and expected outcomes ...
# 2  What role does the NIH play in the development...
# 3  Whaat is the BrIDGs Program and howw can it su...
# 4  Could you elaborate on the eligibility of Hisp...
# 5  What NIH say about cost sharing and how many a...
# 6  Wht is the role of the Adminstrative Core in a...
# 7       what national institute of mental health do?
# 8       Wht is PHS in the context of biotech collab?
# 9                             Wht r DHHS reglations?
#
#                                   reference_contexts  \
# 0  [PAR-25-353: National Cooperative Drug/Device ...
# 1  [PAR-25-353: National Cooperative Drug/Device ...
# 2  [Summary In summary, the NCDDG Program will su...
# 3  [Research Scope The objective of this NOFO is ...
# 4  [PAR-25-353: National Cooperative Drug/Device ...
# 5  [2. Cost Sharing This NOFO does not require co...
# 6  [Administrative Core Admin Core 6 Required 1 1...
# 7  [the Research Strategy) by all Research Projec...
# 8  [Project Proposed Project Start/Ending Dates P...
# 9  [must be followed. Scientific Core When prepar...
#
#                                            reference  \
# 0  To submit an application for the National Coop...
# 1  The objectives of the NCDDG program are to adv...
# 2  The NIH is expected to facilitate the interact...
# 3  The NIH Bridging Interventional Development Ga...
# 4  Hispanic-serving Institutions are encouraged t...
# 5  The NIH does not require cost sharing as defin...
# 6  The Administrative Core is a required componen...
# 7  The National Institute of Mental Health (NIMH)...
# 8  PHS refers to the PHS 398 Cover Page Supplemen...
# 9  The DHHS regulations pertain to research invol...
#
#                        synthesizer_name
# 0  single_hop_specifc_query_synthesizer
# 1  single_hop_specifc_query_synthesizer
# 2  single_hop_specifc_query_synthesizer
# 3  single_hop_specifc_query_synthesizer
# 4  single_hop_specifc_query_synthesizer
# 5  single_hop_specifc_query_synthesizer
# 6  single_hop_specifc_query_synthesizer
# 7  single_hop_specifc_query_synthesizer
# 8  single_hop_specifc_query_synthesizer
# 9  single_hop_specifc_query_synthesizer

# %% [markdown]
# ### Invoke the Base RAG Chain for Each Generated Question Above
# Add the response and retrieved contexts to the test dataset as they will be needed in the evaluation process.

# %%
for test_row in dataset:
  response = base_rag_chain.invoke({"question" : test_row.eval_sample.user_input})
  test_row.eval_sample.response = response["response"]
  test_row.eval_sample.retrieved_contexts = [context.page_content for context in response["context"]]

# %% [markdown]
# ### Initialize a Base Evaluation Dataset

# %%
from ragas import EvaluationDataset

evaluation_dataset = EvaluationDataset.from_pandas(dataset.to_pandas())

# %% [markdown]
# ### Run the Evaluation on the Base Embeddings Model
# Using all of the default metrics: LLMContextRecall, Faithfulness, FactualCorrectness, ResponseRelevancy, ContextEntityRecall, NoiseSensitivity
#
# It's interesting to note that the base model performed absolutely terribly for all the metrics with the best score being just 25% for faithfulness. This would seem to suggest that we would be mistaken to not even consider fine-tuning the embeddings model for this specific use case no matter our fine-tuning configuration.

# %%
from ragas import evaluate
from ragas.llms import LangchainLLMWrapper

evaluator_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4o"))

# %%
from ragas.metrics import LLMContextRecall, Faithfulness, FactualCorrectness, ResponseRelevancy, ContextEntityRecall, NoiseSensitivity
from ragas import evaluate, RunConfig

custom_run_config = RunConfig(timeout=360)

result = evaluate(
    dataset=evaluation_dataset,
    metrics=[LLMContextRecall(), Faithfulness(), FactualCorrectness(), ResponseRelevancy(), ContextEntityRecall(), NoiseSensitivity()],
    llm=evaluator_llm,
    run_config=custom_run_config
)
result
# Out:
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]
# ERROR:ragas.executor:Exception raised in Job[32]: TypeError(ufunc 'invert' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe'')
# ERROR:ragas.executor:Exception raised in Job[20]: TypeError(ufunc 'invert' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe'')
# ERROR:ragas.executor:Exception raised in Job[38]: TypeError(ufunc 'invert' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe'')
# ERROR:ragas.executor:Exception raised in Job[17]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29671, Requested 1104. Please try again in 1.55s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# ERROR:ragas.executor:Exception raised in Job[8]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29091, Requested 1764. Please try again in 1.71s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# ERROR:ragas.executor:Exception raised in Job[14]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29690, Requested 1097. Please try again in 1.574s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# ERROR:ragas.executor:Exception raised in Job[44]: TypeError(ufunc 'invert' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe'')
# ERROR:ragas.executor:Exception raised in Job[11]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29728, Requested 1540. Please try again in 2.536s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# ERROR:ragas.executor:Exception raised in Job[25]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29136, Requested 1098. Please try again in 468ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# ERROR:ragas.executor:Exception raised in Job[26]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29413, Requested 1111. Please try again in 1.048s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# ERROR:ragas.executor:Exception raised in Job[56]: TypeError(ufunc 'invert' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe'')
# ERROR:ragas.executor:Exception raised in Job[50]: TypeError(ufunc 'invert' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe'')
# ERROR:ragas.executor:Exception raised in Job[2]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29311, Requested 1539. Please try again in 1.7s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# ERROR:ragas.executor:Exception raised in Job[0]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[4]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[1]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[5]: TimeoutError()
# {'context_recall': 0.0000, 'faithfulness': 0.2500, 'factual_correctness': nan, 'answer_relevancy': 0.1000, 'context_entity_recall': 0.0000, 'noise_sensitivity_relevant': 0.0000}

# %% [markdown]
# ### Invoke the Fine-Tuned RAG Chain for Each Generated Question Above

# %%
for test_row in dataset:
  response = finetune_rag_chain.invoke({"question" : test_row.eval_sample.user_input})
  test_row.eval_sample.response = response["response"]
  test_row.eval_sample.retrieved_contexts = [context.page_content for context in response["context"]]

# %% [markdown]
# ### Initialize a Fine-Tuned Evaluation Dataset

# %%
evaluation_dataset = EvaluationDataset.from_pandas(dataset.to_pandas())

# %% [markdown]
# ### Run the Evaluation on the Fine-Tuned Embeddings Model
# Unfortunately, while the metrics are all improved by the fine-tuning, they're still not quite where we want them to be. Which suggests either some additional fine-tuning may be needed or else some other tweaking of the RAG chain. It could also be the case that the synthetic data generation did not do a good job identifying question/answer pairs.

# %%
from ragas.metrics import LLMContextRecall, Faithfulness, FactualCorrectness, ResponseRelevancy, ContextEntityRecall, NoiseSensitivity
from ragas import evaluate, RunConfig

custom_run_config = RunConfig(timeout=360)

result = evaluate(
    dataset=evaluation_dataset,
    metrics=[LLMContextRecall(), Faithfulness(), FactualCorrectness(), ResponseRelevancy(), ContextEntityRecall(), NoiseSensitivity()],
    llm=evaluator_llm,
    run_config=custom_run_config
)
result
# Out:
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]
# ERROR:ragas.executor:Exception raised in Job[20]: TypeError(ufunc 'invert' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe'')
# ERROR:ragas.executor:Exception raised in Job[0]: RateLimitError(Error code: 429 - {'error': {'message': 'Request too large for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Requested 35498. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# ERROR:ragas.executor:Exception raised in Job[4]: RateLimitError(Error code: 429 - {'error': {'message': 'Request too large for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Requested 34990. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# ERROR:ragas.executor:Exception raised in Job[1]: RateLimitError(Error code: 429 - {'error': {'message': 'Request too large for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Requested 35780. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# ERROR:ragas.executor:Exception raised in Job[5]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[7]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[10]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[11]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[12]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[13]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[16]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[18]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[17]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[19]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[32]: TypeError(ufunc 'invert' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe'')
# ERROR:ragas.executor:Exception raised in Job[44]: TypeError(ufunc 'invert' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe'')
# ERROR:ragas.executor:Exception raised in Job[22]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[50]: TypeError(ufunc 'invert' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe'')
# ERROR:ragas.executor:Exception raised in Job[24]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[25]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[36]: RateLimitError(Error code: 429 - {'error': {'message': 'Request too large for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Requested 63199. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# ERROR:ragas.executor:Exception raised in Job[37]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Used 29176, Requested 1593. Please try again in 1.538s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# ERROR:ragas.executor:Exception raised in Job[56]: TypeError(ufunc 'invert' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe'')
# ERROR:ragas.executor:Exception raised in Job[40]: RateLimitError(Error code: 429 - {'error': {'message': 'Request too large for gpt-4o in organization org-fG4XzykR5yuSt2Wp6ZlK7gAJ on tokens per min (TPM): Limit 30000, Requested 62879. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# ERROR:ragas.executor:Exception raised in Job[28]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[29]: TimeoutError()
# ERROR:ragas.executor:Exception raised in Job[41]: TimeoutError()
# {'context_recall': 0.2000, 'faithfulness': 0.2500, 'factual_correctness': 0.3920, 'answer_relevancy': 0.4904, 'context_entity_recall': 0.1250, 'noise_sensitivity_relevant': 0.0000}
